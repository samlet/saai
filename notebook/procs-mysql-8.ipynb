# %%
from mysql.connector import (connection)

cnx = connection.MySQLConnection(user='root', password='root',
                                 host='127.0.0.1',
                                 database='test')
cnx.close()

# %%
from __future__ import print_function

import mysql.connector
from mysql.connector import errorcode

DB_NAME = 'employees'

TABLES = {}
TABLES['employees'] = (
    "CREATE TABLE `employees` ("
    "  `emp_no` int(11) NOT NULL AUTO_INCREMENT,"
    "  `birth_date` date NOT NULL,"
    "  `first_name` varchar(14) NOT NULL,"
    "  `last_name` varchar(16) NOT NULL,"
    "  `gender` enum('M','F') NOT NULL,"
    "  `hire_date` date NOT NULL,"
    "  PRIMARY KEY (`emp_no`)"
    ") ENGINE=InnoDB")

TABLES['departments'] = (
    "CREATE TABLE `departments` ("
    "  `dept_no` char(4) NOT NULL,"
    "  `dept_name` varchar(40) NOT NULL,"
    "  PRIMARY KEY (`dept_no`), UNIQUE KEY `dept_name` (`dept_name`)"
    ") ENGINE=InnoDB")

TABLES['salaries'] = (
    "CREATE TABLE `salaries` ("
    "  `emp_no` int(11) NOT NULL,"
    "  `salary` int(11) NOT NULL,"
    "  `from_date` date NOT NULL,"
    "  `to_date` date NOT NULL,"
    "  PRIMARY KEY (`emp_no`,`from_date`), KEY `emp_no` (`emp_no`),"
    "  CONSTRAINT `salaries_ibfk_1` FOREIGN KEY (`emp_no`) "
    "     REFERENCES `employees` (`emp_no`) ON DELETE CASCADE"
    ") ENGINE=InnoDB")

TABLES['dept_emp'] = (
    "CREATE TABLE `dept_emp` ("
    "  `emp_no` int(11) NOT NULL,"
    "  `dept_no` char(4) NOT NULL,"
    "  `from_date` date NOT NULL,"
    "  `to_date` date NOT NULL,"
    "  PRIMARY KEY (`emp_no`,`dept_no`), KEY `emp_no` (`emp_no`),"
    "  KEY `dept_no` (`dept_no`),"
    "  CONSTRAINT `dept_emp_ibfk_1` FOREIGN KEY (`emp_no`) "
    "     REFERENCES `employees` (`emp_no`) ON DELETE CASCADE,"
    "  CONSTRAINT `dept_emp_ibfk_2` FOREIGN KEY (`dept_no`) "
    "     REFERENCES `departments` (`dept_no`) ON DELETE CASCADE"
    ") ENGINE=InnoDB")

TABLES['dept_manager'] = (
    "  CREATE TABLE `dept_manager` ("
    "  `dept_no` char(4) NOT NULL,"
    "  `emp_no` int(11) NOT NULL,"
    "  `from_date` date NOT NULL,"
    "  `to_date` date NOT NULL,"
    "  PRIMARY KEY (`emp_no`,`dept_no`),"
    "  KEY `emp_no` (`emp_no`),"
    "  KEY `dept_no` (`dept_no`),"
    "  CONSTRAINT `dept_manager_ibfk_1` FOREIGN KEY (`emp_no`) "
    "     REFERENCES `employees` (`emp_no`) ON DELETE CASCADE,"
    "  CONSTRAINT `dept_manager_ibfk_2` FOREIGN KEY (`dept_no`) "
    "     REFERENCES `departments` (`dept_no`) ON DELETE CASCADE"
    ") ENGINE=InnoDB")

TABLES['titles'] = (
    "CREATE TABLE `titles` ("
    "  `emp_no` int(11) NOT NULL,"
    "  `title` varchar(50) NOT NULL,"
    "  `from_date` date NOT NULL,"
    "  `to_date` date DEFAULT NULL,"
    "  PRIMARY KEY (`emp_no`,`title`,`from_date`), KEY `emp_no` (`emp_no`),"
    "  CONSTRAINT `titles_ibfk_1` FOREIGN KEY (`emp_no`)"
    "     REFERENCES `employees` (`emp_no`) ON DELETE CASCADE"
    ") ENGINE=InnoDB")

# %%
import mysql
cnx = mysql.connector.connect(user='root', password='root')
cursor = cnx.cursor()

# %%
def create_database(cursor):
    try:
        cursor.execute(
            "CREATE DATABASE {} DEFAULT CHARACTER SET 'utf8'".format(DB_NAME))
    except mysql.connector.Error as err:
        print("Failed creating database: {}".format(err))
        exit(1)

try:
    cursor.execute("USE {}".format(DB_NAME))
except mysql.connector.Error as err:
    print("Database {} does not exists.".format(DB_NAME))
    if err.errno == errorcode.ER_BAD_DB_ERROR:
        create_database(cursor)
        print("Database {} created successfully.".format(DB_NAME))
        cnx.database = DB_NAME
    else:
        print(err)
        exit(1)

# %%
for table_name in TABLES:
    table_description = TABLES[table_name]
    try:
        print("Creating table {}: ".format(table_name), end='')
        cursor.execute(table_description)
    except mysql.connector.Error as err:
        if err.errno == errorcode.ER_TABLE_EXISTS_ERROR:
            print("already exists.")
        else:
            print(err.msg)
    else:
        print("OK")

cursor.close()
cnx.close()
# Out:
# Creating table employees: already exists.
# Creating table departments: already exists.
# Creating table salaries: already exists.
# Creating table dept_emp: already exists.
# Creating table dept_manager: already exists.
# Creating table titles: already exists.

# %%
from __future__ import print_function
from datetime import date, datetime, timedelta
import mysql.connector

# cnx = mysql.connector.connect(user='scott', database='employees')
cnx = mysql.connector.connect(user='root', password='root', database='employees')
cursor = cnx.cursor()

tomorrow = datetime.now().date() + timedelta(days=1)

add_employee = ("INSERT INTO employees "
               "(first_name, last_name, hire_date, gender, birth_date) "
               "VALUES (%s, %s, %s, %s, %s)")
add_salary = ("INSERT INTO salaries "
              "(emp_no, salary, from_date, to_date) "
              "VALUES (%(emp_no)s, %(salary)s, %(from_date)s, %(to_date)s)")

data_employee = ('Geert', 'Vanderkelen', tomorrow, 'M', date(1977, 6, 14))

# Insert new employee
cursor.execute(add_employee, data_employee)
emp_no = cursor.lastrowid

# Insert salary information
data_salary = {
  'emp_no': emp_no,
  'salary': 50000,
  'from_date': tomorrow,
  'to_date': date(9999, 1, 1),
}
cursor.execute(add_salary, data_salary)

# Make sure data is committed to the database
cnx.commit()

cursor.close()
cnx.close()

# %%
import datetime
import mysql.connector

# cnx = mysql.connector.connect(user='scott', database='employees')
cnx = mysql.connector.connect(user='root', password='root', database='employees')
cursor = cnx.cursor()

query = ("SELECT first_name, last_name, hire_date FROM employees "
         "WHERE hire_date BETWEEN %s AND %s")

hire_start = datetime.date(1999, 1, 1)
hire_end = datetime.date(1999, 12, 31)

cursor.execute(query, (hire_start, hire_end))

for (first_name, last_name, hire_date) in cursor:
  print("{}, {} was hired on {:%d %b %Y}".format(
    last_name, first_name, hire_date))

cursor.close()
cnx.close()
# Out:
# Haddadi, Lillian was hired on 30 Apr 1999
# Piveteau, Hironoby was hired on 23 Mar 1999
# DuCasse, Dietrich was hired on 30 Mar 1999
# Tokunaga, Aimee was hired on 28 Oct 1999
# Meriste, Neven was hired on 17 Jul 1999
# Rossi, Samphel was hired on 10 Jan 1999
# Merey, JoAnne was hired on 06 Nov 1999
# Magliocco, Malu was hired on 23 Aug 1999
# Pettis, Chaosheng was hired on 17 Feb 1999
# Guenter, Kensei was hired on 04 Jan 1999
# Rosaz, Zvonko was hired on 01 Feb 1999
# Kushner, Billie was hired on 24 Jan 1999
# Casperson, Percy was hired on 08 Oct 1999
# Erni, Mooi was hired on 01 Oct 1999
# Marzano, Shawna was hired on 04 Jan 1999
# Mukaidono, Mayumi was hired on 22 Jan 1999
# Ranst, Jingling was hired on 19 Jun 1999
# Bazzichi, Yuuichi was hired on 01 Jul 1999
# Rullman, Tetsurou was hired on 06 Mar 1999
# Attimonelli, Junichi was hired on 30 Jan 1999
# Siepmann, Adil was hired on 31 Dec 1999
# Llado, Mabry was hired on 24 Jan 1999
# Kragelund, Pragnesh was hired on 29 May 1999
# Undy, Yonghoan was hired on 29 Sep 1999
# Poulakidas, Jinxi was hired on 24 Jun 1999
# Veldwijk, Barry was hired on 13 Apr 1999
# Percebois, Honglan was hired on 03 Mar 1999
# Sinicrope, Brewster was hired on 04 Dec 1999
# Servieres, Leon was hired on 08 Jan 1999
# Haldar, Vesna was hired on 08 Jan 1999
# Panangaden, Aiman was hired on 12 Jul 1999
# Basawa, Paloma was hired on 05 Feb 1999
# Narlikar, Fumino was hired on 01 Apr 1999
# Percebois, Adhemar was hired on 20 Feb 1999
# Matteis, Sanjoy was hired on 25 May 1999
# Lortz, Seongbin was hired on 01 Apr 1999
# Biran, Juichirou was hired on 30 Sep 1999
# Salverda, Ugo was hired on 14 Jun 1999
# Baba, Bedir was hired on 09 Jan 1999
# Baak, Mingdong was hired on 30 Jan 1999
# Staudhammer, Tadanori was hired on 10 Apr 1999
# Chandrasekhar, Eberhardt was hired on 04 Mar 1999
# Strandh, Parviz was hired on 22 Feb 1999
# Waterhouse, Yannis was hired on 08 May 1999
# Zumaque, Zhilian was hired on 04 Mar 1999
# Giveon, Baruch was hired on 27 Oct 1999
# Pauthner, Candido was hired on 01 Apr 1999
# Gilg, Snehasis was hired on 14 Nov 1999
# Yoshimura, Chuanyi was hired on 11 Mar 1999
# Rajcani, Tzvetan was hired on 03 May 1999
# Melter, Elvia was hired on 16 Jun 1999
# Pena, Tianruo was hired on 26 Jan 1999
# Perly, Herbert was hired on 08 Feb 1999
# Luca, Uta was hired on 05 Jun 1999
# Lorys, Kenton was hired on 07 Mar 1999
# Seuren, Anneli was hired on 26 Jan 1999
# Nishimukai, Leaf was hired on 29 Jul 1999
# Suermann, Shaz was hired on 16 Aug 1999
# Erol, Breannda was hired on 24 Feb 1999
# Kawashimo, Sadun was hired on 18 Aug 1999
# Orsini, Youssef was hired on 28 Aug 1999
# Porotnikoff, Shmuel was hired on 05 Sep 1999
# Monarch, Thanasis was hired on 21 Oct 1999
# Taubman, Yuichiro was hired on 04 Jun 1999
# Olivero, Sanjay was hired on 11 Jun 1999
# Melton, Arup was hired on 24 Aug 1999
# Halevi, Uriel was hired on 28 Jan 1999
# Anandan, Gaurav was hired on 02 Jun 1999
# Shumilov, Tooru was hired on 03 Jun 1999
# Ramaiah, Christophe was hired on 13 Jan 1999
# Markovitch, Ferdinand was hired on 15 Mar 1999
# Krohn, Subbu was hired on 08 Aug 1999
# Tempesti, Dmitry was hired on 06 Apr 1999
# Basagni, Lein was hired on 12 Feb 1999
# Baumann, Quingbo was hired on 20 Jan 1999
# Polajnar, Temple was hired on 28 Sep 1999
# Sankaranarayanan, Chaosheng was hired on 15 Apr 1999
# Bhattacharjee, Shen was hired on 07 Jan 1999
# Francisci, Joydip was hired on 25 Jun 1999
# Paludetto, Irene was hired on 27 Feb 1999
# Chepyzhov, Prodip was hired on 20 Jun 1999
# Christ, Dante was hired on 27 Jan 1999
# Dratva, Sven was hired on 25 Apr 1999
# Pappas, Masoud was hired on 25 Jan 1999
# Malabarba, Martijn was hired on 16 Jun 1999
# Alameldin, Avishai was hired on 07 Jan 1999
# Koblick, Giri was hired on 01 Mar 1999
# Morris, Siamak was hired on 01 Mar 1999
# Kowalchuk, Lucien was hired on 19 Jan 1999
# Matzen, Demos was hired on 27 Apr 1999
# Chimia, Hsiangchu was hired on 27 Aug 1999
# Leppanen, Piyawadee was hired on 25 Feb 1999
# Danecki, Lijia was hired on 18 Jun 1999
# Katzenelson, Subhankar was hired on 18 Sep 1999
# Anguita, Isaac was hired on 14 Jun 1999
# Zwicker, Fumiko was hired on 23 Nov 1999
# Heyers, Yannis was hired on 28 Sep 1999
# Doering, Youngkon was hired on 18 Jul 1999
# Teitelbaum, Kankanahalli was hired on 25 Sep 1999
# Sinicrope, Mihalis was hired on 04 Mar 1999
# Compeau, Weiru was hired on 08 Mar 1999
# Denis, Magy was hired on 05 Jun 1999
# Nourani, Ewing was hired on 01 Jan 1999
# Radhakrishnan, Guiseppe was hired on 10 Nov 1999
# Stille, Alejandro was hired on 18 Jul 1999
# Rouquie, Leon was hired on 12 Jul 1999
# Majewski, Gudjon was hired on 26 Oct 1999
# Crooks, Fumitake was hired on 06 Aug 1999
# Varley, Martial was hired on 19 Apr 1999
# Harbusch, Irena was hired on 22 Sep 1999
# Benaini, Teunis was hired on 17 Apr 1999
# Miake, Zhonghui was hired on 26 Aug 1999
# Simmen, Ghassan was hired on 07 Mar 1999
# Janetzko, Zhaofang was hired on 29 Oct 1999
# Garnick, True was hired on 16 Jan 1999
# Peternell, Gor was hired on 19 Sep 1999
# Tempesti, Huican was hired on 22 May 1999
# Berztiss, Emdad was hired on 05 Jul 1999
# Validov, Francoise was hired on 08 Aug 1999
# Decaestecker, Mads was hired on 21 Feb 1999
# Bernini, Khun was hired on 31 Aug 1999
# Munos, Mostafa was hired on 21 Jun 1999
# Worfolk, Saeko was hired on 04 Apr 1999
# Encarnacion, Susanna was hired on 12 Feb 1999
# Halevi, Foong was hired on 03 Aug 1999
# Mondadori, Abdulla was hired on 18 Jan 1999
# Eppinger, Denny was hired on 03 Aug 1999
# Hardjono, Eishiro was hired on 21 May 1999
# Katiyar, Debatosh was hired on 20 Jul 1999
# Mersereau, Guenter was hired on 22 Apr 1999
# Saoudi, Jianhao was hired on 12 Oct 1999
# Pargas, Ulf was hired on 11 Apr 1999
# Kornatzky, Yonghong was hired on 28 Oct 1999
# Azevdeo, Masoud was hired on 04 Apr 1999
# DeMori, Nevio was hired on 13 Jan 1999
# Benzaken, Parviz was hired on 30 Mar 1999
# Kaltofen, Yonghong was hired on 17 Mar 1999
# Tokunaga, Arno was hired on 10 Jan 1999
# Gladwell, Sangeeta was hired on 25 Jan 1999
# Jording, Karsten was hired on 13 Nov 1999
# Vitiello, Yunming was hired on 23 May 1999
# Auyong, Chrisa was hired on 09 Jan 1999
# Welham, Hailing was hired on 20 Aug 1999
# Levergood, Hailing was hired on 21 Jul 1999
# Baak, Florina was hired on 23 Feb 1999
# Itzigehl, Yonghong was hired on 15 May 1999
# Coney, Padma was hired on 14 May 1999
# Middleton, Hatim was hired on 17 Aug 1999
# Hartvigsen, Rosli was hired on 15 Jun 1999
# Sinicrope, Luerbio was hired on 16 Aug 1999
# Preusig, Leif was hired on 29 Mar 1999
# Baba, Mokhtar was hired on 22 Aug 1999
# Cincotta, Along was hired on 04 Jun 1999
# Kropatsch, Geoff was hired on 18 Jun 1999
# Verhaegen, Mantis was hired on 07 Apr 1999
# Brizzi, Mori was hired on 23 Feb 1999
# Samarati, Bogdan was hired on 19 Jul 1999
# Jonsson, Jianhui was hired on 22 Feb 1999
# Hellwagner, Mart was hired on 17 Jun 1999
# Frezza, Kamakshi was hired on 03 Apr 1999
# Meriste, Gad was hired on 17 Feb 1999
# Sidou, Horward was hired on 07 Apr 1999
# Foong, Tonia was hired on 16 Jun 1999
# Lorie, Ymte was hired on 18 Jul 1999
# Ghandeharizadeh, Arno was hired on 16 Jun 1999
# Jording, Shan was hired on 24 Feb 1999
# Rijckaert, Hugh was hired on 25 Mar 1999
# Debuse, Shalesh was hired on 24 Mar 1999
# Lorie, Rildo was hired on 24 Mar 1999
# Gide, Adamantios was hired on 26 Sep 1999
# Castellani, Serap was hired on 13 May 1999
# Masada, Lidong was hired on 17 Jun 1999
# Garrabrants, Saeed was hired on 10 May 1999
# Pappas, Tsutomu was hired on 16 Feb 1999
# Velasco, Rosalyn was hired on 15 Apr 1999
# Emmerich, Constantine was hired on 31 May 1999
# Brookman, Frederique was hired on 07 Nov 1999
# Mellouli, Mechthild was hired on 13 Jan 1999
# Speek, Takahito was hired on 11 Feb 1999
# Ramsey, Martien was hired on 25 Apr 1999
# Sigstam, Fusako was hired on 10 Feb 1999
# Valtorta, Jaewon was hired on 04 Apr 1999
# Munch, Akeno was hired on 24 Jul 1999
# Brodie, Dannz was hired on 11 Jan 1999
# Kushner, Zhenbing was hired on 08 Mar 1999
# Giaccio, Adil was hired on 27 May 1999
# Miyakawa, Pramod was hired on 10 Sep 1999
# Erdmenger, Mooi was hired on 23 Mar 1999
# Chachaty, Kamran was hired on 19 Jan 1999
# Worfolk, Atreye was hired on 12 Jul 1999
# Rodier, Marit was hired on 20 Jan 1999
# Luon, Lorien was hired on 23 Dec 1999
# Begiun, Vivian was hired on 23 Feb 1999
# Syang, Branimir was hired on 11 Dec 1999
# Mamelak, Stein was hired on 05 Aug 1999
# Billawala, Erzsebet was hired on 26 Jun 1999
# Boyle, Basant was hired on 26 Jan 1999
# Zykh, Toshiko was hired on 09 Jan 1999
# Schoegge, Vishwani was hired on 20 Sep 1999
# DuBourdieux, Zhongwei was hired on 19 Dec 1999
# Butterworth, Christophe was hired on 14 Jul 1999
# Auria, Hongzue was hired on 01 Jan 1999
# Spelt, Pintsang was hired on 01 Oct 1999
# Servieres, Saniya was hired on 01 May 1999
# Redmiles, Mansur was hired on 01 Aug 1999
# Bardell, Parke was hired on 17 Jun 1999
# Kushner, Sumali was hired on 30 Oct 1999
# Kragelund, Vishv was hired on 07 Sep 1999
# Paludetto, Kazuhisa was hired on 13 Aug 1999
# Selvestrel, Anwar was hired on 06 Jun 1999
# Luke, Anoosh was hired on 28 Apr 1999
# Verspoor, Miyeon was hired on 08 May 1999
# Ozeki, Gonzalo was hired on 12 Nov 1999
# Condotta, Persi was hired on 16 May 1999
# Sherertz, Constantijn was hired on 04 Mar 1999
# Cronau, Werner was hired on 16 Mar 1999
# Akiyama, Zdislav was hired on 29 May 1999
# Dredge, Mayuri was hired on 27 Jun 1999
# Chiodo, Yannik was hired on 17 Jul 1999
# Pluym, Achilleas was hired on 01 Aug 1999
# Maraist, Bernardo was hired on 20 Jan 1999
# Crooks, Baziley was hired on 06 Aug 1999
# Rosis, Domenick was hired on 25 Feb 1999
# Gire, Nathan was hired on 26 Feb 1999
# Roohalamini, Genevieve was hired on 18 Mar 1999
# Masaki, Randi was hired on 27 Jan 1999
# Polajnar, Shin was hired on 29 Aug 1999
# Millington, Keiichiro was hired on 01 Jul 1999
# Bednarek, Gilbert was hired on 07 Feb 1999
# Serov, Goncalo was hired on 18 Apr 1999
# Dulin, JoAnne was hired on 09 Jun 1999
# Ertl, Randy was hired on 30 Apr 1999
# Solares, Jasminko was hired on 23 Mar 1999
# Homond, Mohammad was hired on 01 Oct 1999
# Tsukuda, Magy was hired on 24 Apr 1999
# Varker, Percy was hired on 11 Oct 1999
# Badr, Moie was hired on 16 Feb 1999
# Srimani, Carrsten was hired on 27 Mar 1999
# Krichel, Apostol was hired on 25 Apr 1999
# Salinas, Vishv was hired on 09 May 1999
# Aseltine, Gino was hired on 07 Feb 1999
# Leuchs, IEEE was hired on 28 Mar 1999
# Bultermann, JoAnna was hired on 25 Jun 1999
# Barinka, Chikara was hired on 09 Mar 1999
# Litecky, Alair was hired on 08 Mar 1999
# Chelton, Geraldo was hired on 26 Jul 1999
# Rosiles, Muneo was hired on 15 Oct 1999
# Reinhard, Shahab was hired on 08 Oct 1999
# Zuberek, Odoardo was hired on 28 Oct 1999
# dAstous, Candido was hired on 20 Jan 1999
# Kemmerer, Gou was hired on 10 Apr 1999
# Katalagarianos, Hatsukazu was hired on 02 Sep 1999
# Vecchi, Ung was hired on 23 Jul 1999
# Quaggetto, Sven was hired on 18 Feb 1999
# Barinka, Guoxiang was hired on 25 Aug 1999
# Rindone, Gill was hired on 13 Jan 1999
# Penz, Bernd was hired on 21 Mar 1999
# Werthner, Leszek was hired on 03 Mar 1999
# Zizka, Alois was hired on 20 Feb 1999
# Driscoll, Tzu was hired on 13 Jan 1999
# Feinberg, Magy was hired on 28 Aug 1999
# Terkki, Mabhin was hired on 17 Jan 1999
# Portugali, Atreyi was hired on 09 Feb 1999
# Tchuente, Honglan was hired on 26 May 1999
# Lichtner, Anyuan was hired on 22 Feb 1999
# Curless, Debaprosad was hired on 14 Mar 1999
# Sankaranarayanan, Kazuhide was hired on 28 Aug 1999
# Gecsei, Vasilii was hired on 09 Jun 1999
# Parascandalo, Lene was hired on 06 Apr 1999
# Danlos, Yongqiao was hired on 26 Mar 1999
# Kalafatis, Nectarios was hired on 27 May 1999
# Negoita, Yuqun was hired on 16 Nov 1999
# Liesche, Susanta was hired on 19 May 1999
# Weedman, Mori was hired on 29 Jan 1999
# Antonakopoulos, Qunsheng was hired on 08 Oct 1999
# Duclos, Duke was hired on 17 Feb 1999
# Birjandi, Aleksander was hired on 21 Nov 1999
# Azumi, Shahar was hired on 25 Mar 1999
# Crelier, Mansur was hired on 17 Jul 1999
# Kakkad, Martine was hired on 28 Jan 1999
# Curless, Paddy was hired on 07 Jan 1999
# Poujol, Larisa was hired on 28 Oct 1999
# Ramsay, Tamiya was hired on 08 Jun 1999
# Luft, Luerbio was hired on 27 Feb 1999
# Herbst, Heekeun was hired on 20 Feb 1999
# Junet, Jeanne was hired on 06 Apr 1999
# Eldridge, Teiji was hired on 27 Nov 1999
# Cappelletti, Houman was hired on 25 Mar 1999
# Suessmith, Gaurav was hired on 07 Jun 1999
# Covnot, Marin was hired on 26 Feb 1999
# Henders, Yinghua was hired on 24 Aug 1999
# Verhoeff, Murthy was hired on 29 Oct 1999
# Flasterstein, Turgut was hired on 02 Dec 1999
# McFarlan, Werner was hired on 09 Jan 1999
# Ertl, Hsiangchu was hired on 12 Jun 1999
# Goodrum, Koichi was hired on 17 May 1999
# Olivero, Yurij was hired on 16 Oct 1999
# Barbanera, Martial was hired on 15 Apr 1999
# Katiyar, Sangeeta was hired on 25 Feb 1999
# Chartres, Xinan was hired on 26 Jun 1999
# Kampfer, Rayond was hired on 04 Feb 1999
# Falco, Ingemar was hired on 24 Jan 1999
# Smailagic, Herbert was hired on 19 Mar 1999
# Ghemri, Manton was hired on 30 Dec 1999
# Hofting, Kazuhiko was hired on 19 Aug 1999
# Swist, Make was hired on 26 May 1999
# Einsfeld, Hidde was hired on 12 Mar 1999
# Zirintsis, Shahid was hired on 03 Feb 1999
# Duclos, Genta was hired on 22 Jul 1999
# Gyimothy, Lucien was hired on 17 Mar 1999
# Kalsbeek, Mart was hired on 05 Mar 1999
# Spinelli, Arto was hired on 02 Dec 1999
# Standera, Mingzeng was hired on 25 May 1999
# Leuchs, Kristina was hired on 25 Mar 1999
# Piancastelli, Kazuhiro was hired on 09 Jan 1999
# Stavenow, Vasilii was hired on 30 Dec 1999
# Conry, Cordelia was hired on 30 Mar 1999
# Manders, Zhaofang was hired on 07 Mar 1999
# Birjandi, Tsutomu was hired on 12 Mar 1999
# Hainaut, Leni was hired on 11 Aug 1999
# Marciano, Cordelia was hired on 17 Apr 1999
# Shackel, Tommaso was hired on 18 Feb 1999
# Schwabacher, Bowen was hired on 04 Aug 1999
# Coombs, Sergi was hired on 12 May 1999
# Gimarc, Kwangho was hired on 13 Jan 1999
# Kavanagh, Mabry was hired on 11 Dec 1999
# Birjandi, Ioana was hired on 18 Jun 1999
# Ashish, Sariel was hired on 09 Mar 1999
# Marwedel, Gou was hired on 02 Nov 1999
# Slutz, Geoffry was hired on 01 May 1999
# Wroclawski, Tsz was hired on 12 Mar 1999
# Socorro, Tomoyuki was hired on 07 Apr 1999
# Baby, Guozhong was hired on 23 Nov 1999
# Rande, Hitomi was hired on 28 Aug 1999
# Borovoy, Masali was hired on 13 Oct 1999
# Cincotta, Kazuhiko was hired on 18 Apr 1999
# Fujisawa, Jahangir was hired on 08 Jan 1999
# Trumbly, Mikhail was hired on 04 Jan 1999
# Narahari, Mingzeng was hired on 10 Jun 1999
# Broomell, Oscar was hired on 22 Jan 1999
# Rosti, Fayez was hired on 15 Feb 1999
# Olivero, Hyuckchul was hired on 06 Apr 1999
# Ellozy, Kellie was hired on 07 Jun 1999
# Rahier, Werner was hired on 18 Mar 1999
# Underwood, Perla was hired on 03 Jun 1999
# Matzel, Abdelaziz was hired on 01 Sep 1999
# Benaini, Irene was hired on 20 May 1999
# Waleschkowski, Girolamo was hired on 27 Sep 1999
# Zschoche, Mariusz was hired on 21 Nov 1999
# Demos, Sadok was hired on 28 Feb 1999
# Cherinka, Wilmer was hired on 25 Jun 1999
# Luef, Serif was hired on 23 Sep 1999
# Frolund, Aloke was hired on 23 Apr 1999
# Trachtenberg, Navid was hired on 09 Feb 1999
# Pellegrinelli, Jaber was hired on 07 Mar 1999
# Magalhaes, Yinlin was hired on 08 Jan 1999
# Bolotov, Saeko was hired on 07 Jun 1999
# Validov, Premsyl was hired on 06 Aug 1999
# Griswold, Oscal was hired on 27 Jul 1999
# Deyuan, Leaf was hired on 02 Jun 1999
# Heinisuo, Weiyi was hired on 25 Jul 1999
# Usdin, Caolyn was hired on 04 Jan 1999
# Bage, Shao was hired on 19 Oct 1999
# Thiria, Jacopo was hired on 20 Jul 1999
# Yoshizawa, Atreyi was hired on 13 Feb 1999
# Douceur, Mohammad was hired on 27 Feb 1999
# Benzmuller, Bernt was hired on 20 Apr 1999
# Senzako, Ranan was hired on 10 Jan 1999
# Oskamp, Janalee was hired on 30 Jan 1999
# Danner, Remco was hired on 29 May 1999
# Manders, Guadalupe was hired on 23 Jan 1999
# Lorho, Sumant was hired on 03 Apr 1999
# Masada, Yurii was hired on 16 Mar 1999
# Engberts, Roddy was hired on 13 Feb 1999
# Rajaraman, Yuguang was hired on 16 Oct 1999
# Erie, Vitaly was hired on 25 Aug 1999
# Callaway, Chiradeep was hired on 19 Jan 1999
# Sadowsky, Oscal was hired on 27 Mar 1999
# Turnbull, Vidar was hired on 07 May 1999
# Pepe, Laurentiu was hired on 14 Mar 1999
# Milicia, Guther was hired on 06 Jul 1999
# Suppi, Tesuya was hired on 28 Aug 1999
# Bernardinello, Noritoshi was hired on 11 Apr 1999
# Melichar, Tze was hired on 15 Jul 1999
# Luit, Feixiong was hired on 28 Jul 1999
# Brendel, Kasidit was hired on 23 Feb 1999
# Ohori, DeForest was hired on 06 Nov 1999
# Selvestrel, Kousuke was hired on 01 May 1999
# Foote, Chenxi was hired on 28 Apr 1999
# Gide, Uli was hired on 21 Aug 1999
# Sambasivam, Oldrich was hired on 05 May 1999
# Cmelik, Yucai was hired on 05 Jan 1999
# Mattern, Kerryn was hired on 09 Apr 1999
# Unno, Toshimori was hired on 14 Aug 1999
# Perly, Mabhin was hired on 26 Apr 1999
# Krogh, Francoise was hired on 27 Jan 1999
# Milicic, Zissis was hired on 02 May 1999
# Braunschweig, Zhilian was hired on 29 Jan 1999
# DuBourdieux, Kazuhiro was hired on 27 Nov 1999
# Yemenis, Atilio was hired on 06 Feb 1999
# Naudin, Shai was hired on 24 Jan 1999
# Sundgren, Huiqun was hired on 21 Apr 1999
# Swen, Huei was hired on 19 Nov 1999
# Mamelak, Yefim was hired on 29 May 1999
# Ducloy, Tse was hired on 23 Jun 1999
# England, Nahum was hired on 20 Apr 1999
# Yurov, Zdislav was hired on 02 Jun 1999
# Baez, Kayoko was hired on 03 May 1999
# Muhlberg, Vidar was hired on 22 Jan 1999
# Hasenauer, Shirish was hired on 06 Aug 1999
# Kamble, Dannz was hired on 18 Dec 1999
# Pettis, Rosalyn was hired on 29 Jun 1999
# Zobel, Vitaly was hired on 15 Nov 1999
# Zallocco, Sandeepan was hired on 10 Aug 1999
# Jording, Valery was hired on 10 Oct 1999
# Fortenbacher, Martijn was hired on 21 Sep 1999
# Godskesen, Parviz was hired on 16 Feb 1999
# Demos, Richard was hired on 07 Aug 1999
# Penttonen, Miyeon was hired on 14 Jan 1999
# Chinin, Claudi was hired on 06 Feb 1999
# Greibach, Nobuyoshi was hired on 10 Dec 1999
# Angot, Roded was hired on 04 Jan 1999
# Templeman, Vishwani was hired on 08 Jan 1999
# Mayerwieser, Joydip was hired on 14 Feb 1999
# Krychniak, KayLiang was hired on 23 Aug 1999
# Kawashimo, Mahendra was hired on 31 Jan 1999
# Kossowski, Youpyo was hired on 04 Jun 1999
# Caine, Hairong was hired on 16 Jan 1999
# Bennet, Manibrata was hired on 10 Feb 1999
# Vrecion, Mariusz was hired on 12 Feb 1999
# Sadowski, Bluma was hired on 09 May 1999
# Radhakrishnan, Chuanti was hired on 22 Jul 1999
# Angiulli, Rajmohan was hired on 13 Feb 1999
# Siochi, Jinya was hired on 25 Feb 1999
# Veccia, Marin was hired on 23 Apr 1999
# Kermarrec, Gianluca was hired on 24 Jan 1999
# Facello, Rosalie was hired on 07 Mar 1999
# Bugrara, Xinyu was hired on 11 Jan 1999
# Zongker, Sudhanshu was hired on 10 Jan 1999
# Mawatari, Zhaofang was hired on 29 Jan 1999
# Cyne, Reinhard was hired on 02 Nov 1999
# Quittner, Dekang was hired on 04 Aug 1999
# Solovay, Ramalingam was hired on 03 Oct 1999
# Pettis, Ortrun was hired on 01 Sep 1999
# Zeilberger, Maria was hired on 06 Apr 1999
# Pero, Giri was hired on 20 Jan 1999
# Swift, Susanna was hired on 23 Jun 1999
# Covnot, Filipp was hired on 02 Jan 1999
# Zwicker, Honesty was hired on 06 Mar 1999
# Merey, Arto was hired on 12 Jun 1999
# Bamford, Fuqing was hired on 21 Apr 1999
# Gronowski, Saniya was hired on 01 Mar 1999
# Waeselynck, IEEE was hired on 06 Jun 1999
# Coorg, Stafford was hired on 08 Mar 1999
# Erdi, Rosine was hired on 26 Aug 1999
# Ranft, Masako was hired on 22 Apr 1999
# Veccia, Vasiliy was hired on 08 Jan 1999
# Stentiford, Almudena was hired on 23 Jul 1999
# Luders, Chiranjit was hired on 17 Apr 1999
# Schonegge, Masanao was hired on 27 Apr 1999
# Merkl, Tuval was hired on 10 Dec 1999
# Camurati, Steve was hired on 02 Mar 1999
# Raczkowsky, Vugranam was hired on 04 Feb 1999
# Braunschweig, Along was hired on 07 May 1999
# Katalagarianos, Amstein was hired on 03 Feb 1999
# Solovay, Fumitake was hired on 28 Oct 1999
# Facello, Juichirou was hired on 23 Apr 1999
# Navazio, Marek was hired on 23 Sep 1999
# Litzkow, Oscal was hired on 07 Mar 1999
# Ranon, Salvador was hired on 17 Sep 1999
# Claffy, Subhash was hired on 12 Feb 1999
# Falco, Janche was hired on 21 Apr 1999
# Vickson, Fumitaka was hired on 08 Apr 1999
# Cannard, Charmane was hired on 31 Jan 1999
# Ranum, Theron was hired on 01 May 1999
# Bach, Youjian was hired on 23 Feb 1999
# Heijenga, Tesuya was hired on 29 Jul 1999
# Kropatsch, Heejo was hired on 25 Feb 1999
# Ibel, Kankanahalli was hired on 23 Jul 1999
# Nourani, Vasiliy was hired on 25 Sep 1999
# Lindenbaum, Bodo was hired on 24 Feb 1999
# Klyachko, Marko was hired on 12 Aug 1999
# Peris, Szabolcs was hired on 19 Oct 1999
# Escriba, Theron was hired on 14 Sep 1999
# Belinskaya, Herb was hired on 06 Mar 1999
# Veccia, Torsten was hired on 27 Jul 1999
# Staelin, Sashi was hired on 20 Jan 1999
# Mahnke, Mrinalini was hired on 06 Oct 1999
# Aloia, Honesty was hired on 19 Jan 1999
# Rossi, Eirik was hired on 16 Jul 1999
# Coney, Spyrose was hired on 30 Jun 1999
# Basawa, Stamatina was hired on 04 Oct 1999
# Percebois, Jeong was hired on 07 Mar 1999
# Thiria, Matk was hired on 26 Mar 1999
# Vendrig, Saeed was hired on 30 Mar 1999
# Birta, Lene was hired on 18 Jun 1999
# Linnainmaa, Martins was hired on 21 Apr 1999
# Hagimont, Gilbert was hired on 20 Sep 1999
# Jarecki, Shalesh was hired on 24 May 1999
# Velasco, Marsha was hired on 22 Sep 1999
# Polajnar, Lenore was hired on 25 Jul 1999
# Dymetman, Goh was hired on 28 Mar 1999
# Parascandalo, Heeju was hired on 08 Jun 1999
# Kambil, Quingbo was hired on 30 Oct 1999
# Piveteau, Jianhua was hired on 02 Jan 1999
# Mapelli, Gian was hired on 20 Apr 1999
# Schwabacher, Kazuhisa was hired on 03 Mar 1999
# Rusterholz, Douadi was hired on 20 Jan 1999
# Mahnke, Weidon was hired on 27 Jul 1999
# Paludetto, Honesty was hired on 16 Aug 1999
# Bach, Mads was hired on 08 Sep 1999
# Brickell, Gino was hired on 17 Apr 1999
# Hennebert, Chaosheng was hired on 20 Feb 1999
# Borovoy, Aleksander was hired on 18 Jan 1999
# Peron, Yannik was hired on 02 May 1999
# Krybus, Noritoshi was hired on 06 Apr 1999
# Merey, Shay was hired on 23 Aug 1999
# Pappas, Yonghong was hired on 24 Mar 1999
# Bach, Martina was hired on 03 Feb 1999
# Montemayor, Somnath was hired on 15 Jan 1999
# Peternell, Maria was hired on 08 Jan 1999
# Mamelak, Kristian was hired on 01 Aug 1999
# Chinin, Sajjad was hired on 02 Aug 1999
# Gulla, Yongmao was hired on 17 Jul 1999
# Binkley, Girolamo was hired on 31 Jan 1999
# Glowinski, Abdulla was hired on 21 May 1999
# Perin, Licheng was hired on 28 Apr 1999
# Copas, Marla was hired on 28 Jun 1999
# Hennebert, Reuven was hired on 30 Jul 1999
# Diderrich, Cordelia was hired on 12 Jun 1999
# Pelc, Pintsang was hired on 19 Mar 1999
# Pezzoli, Jinpo was hired on 10 Sep 1999
# Shobatake, Mandell was hired on 27 Mar 1999
# Schmezko, Shunichi was hired on 25 Feb 1999
# Sambasivam, Sanjoy was hired on 01 Apr 1999
# Zykh, Sudhanshu was hired on 15 Oct 1999
# Makinen, Nectarios was hired on 18 Sep 1999
# Pileggi, Constantino was hired on 08 Feb 1999
# Dusink, Berry was hired on 14 Mar 1999
# Koyama, Kensei was hired on 13 Jan 1999
# Alameldin, Oksana was hired on 22 Feb 1999
# Dusink, Gennadi was hired on 06 Mar 1999
# Mukaidono, Rayond was hired on 20 Jun 1999
# Schmittgen, Shirish was hired on 25 Sep 1999
# Yetto, Stamatina was hired on 30 Aug 1999
# Simkin, Adib was hired on 21 Apr 1999
# Lemarechal, Hairong was hired on 03 May 1999
# Peternell, Remco was hired on 08 Jan 1999
# Baaz, Aksel was hired on 24 Feb 1999
# Lores, Chuanti was hired on 09 Jan 1999
# Ghandeharizadeh, Tsvetan was hired on 23 Feb 1999
# Rodiger, Piyawadee was hired on 20 Nov 1999
# Vural, Aluzio was hired on 26 Feb 1999
# Gischer, Reinhard was hired on 12 Jan 1999
# Gronowski, Makato was hired on 18 Feb 1999
# Fordan, Masami was hired on 29 Jan 1999
# Granlund, Shuji was hired on 05 Apr 1999
# Driscoll, Kazuhiko was hired on 10 May 1999
# Yoshizawa, Leah was hired on 18 Jun 1999
# Kragelund, Hiroyasu was hired on 26 Oct 1999
# Jording, Danae was hired on 01 Jun 1999
# Stafford, Leon was hired on 19 Jan 1999
# Hofting, Mads was hired on 11 Apr 1999
# Makrucki, Gen was hired on 12 Oct 1999
# Kopetz, Abdelwaheb was hired on 14 Aug 1999
# Peroz, Shuky was hired on 10 Jan 1999
# Nitta, Pascal was hired on 10 Apr 1999
# Heinisuo, Luisa was hired on 19 Feb 1999
# Hennings, Fai was hired on 17 Feb 1999
# Luck, Tremaine was hired on 17 Jan 1999
# Butner, Xuejia was hired on 13 Mar 1999
# Shrader, Chuanti was hired on 04 Jan 1999
# Comyn, Gor was hired on 02 May 1999
# Ballarin, Mostafa was hired on 22 May 1999
# Melton, Yuqun was hired on 01 Jan 1999
# Detkin, Xiping was hired on 13 Jan 1999
# Tzvieli, Freyja was hired on 08 Jun 1999
# Oxman, Leandro was hired on 07 May 1999
# Dechter, Guadalupe was hired on 21 Jun 1999
# Doering, Jaewon was hired on 28 Jul 1999
# Schicker, Denis was hired on 21 Jan 1999
# Dehkordi, Gurbir was hired on 07 Feb 1999
# Sewelson, Sangeeta was hired on 27 Aug 1999
# Cichocki, Mabo was hired on 17 Jan 1999
# Facello, Aamod was hired on 24 Apr 1999
# Narahari, Duro was hired on 28 May 1999
# Brodie, Paraskevi was hired on 14 Feb 1999
# Willoner, Nigel was hired on 06 Aug 1999
# Halloran, Xiong was hired on 18 Oct 1999
# Cappello, Subhankar was hired on 23 Feb 1999
# Rosenbaum, Dinkar was hired on 11 Feb 1999
# Tischendorf, Stafford was hired on 23 Jan 1999
# Makrucki, Ottavia was hired on 28 Aug 1999
# Beutelspacher, Tua was hired on 20 Aug 1999
# Lorys, Marsal was hired on 04 Jun 1999
# Valette, Heng was hired on 13 Mar 1999
# Macedo, Radoslaw was hired on 03 Feb 1999
# Nooteboom, Arvin was hired on 03 Dec 1999
# Acton, Breannda was hired on 21 May 1999
# Frezza, Urs was hired on 26 Jan 1999
# Kalafatis, Odinaldo was hired on 25 Jul 1999
# Antonisse, Pramod was hired on 17 Jan 1999
# Hofmeyr, Abdelghani was hired on 22 Apr 1999
# Azevdeo, Sandeepan was hired on 10 Feb 1999
# Harbusch, Jeong was hired on 22 May 1999
# Orsini, Harjit was hired on 19 May 1999
# Stassinopoulos, Kokou was hired on 19 Aug 1999
# Rando, Clyde was hired on 19 Aug 1999
# Garnham, Otmar was hired on 07 Mar 1999
# Kohling, Mang was hired on 28 Dec 1999
# Demir, Shan was hired on 13 Jan 1999
# Veevers, Yinghua was hired on 03 Apr 1999
# Munawer, Bedrich was hired on 21 Oct 1999
# Perko, Kwok was hired on 16 May 1999
# Heydon, Ravishankar was hired on 22 Jan 1999
# Validov, Constantijn was hired on 15 Jul 1999
# Melichar, Piyush was hired on 31 Aug 1999
# Yetto, Clyde was hired on 21 Jun 1999
# Fargier, Mitchel was hired on 21 Jun 1999
# Milicia, Junsik was hired on 30 Sep 1999
# Schneeberger, Sudhanshu was hired on 11 Jun 1999
# Rosis, Yagil was hired on 01 Mar 1999
# Slutz, Shay was hired on 05 Jul 1999
# Kobara, Hein was hired on 03 Jul 1999
# Hammerschmidt, Leif was hired on 24 Sep 1999
# Rosiles, Chiradeep was hired on 10 Oct 1999
# Remmele, Ramzi was hired on 16 Feb 1999
# Yavatkar, Howell was hired on 19 May 1999
# Lorch, Cordelia was hired on 31 Mar 1999
# Chenoweth, Xiaoheng was hired on 31 Jan 1999
# Panienski, Shem was hired on 17 Jun 1999
# Plavsic, Stamatina was hired on 25 Feb 1999
# Verhoeff, Boguslaw was hired on 12 Jan 1999
# Mahnke, Zhiguo was hired on 29 Apr 1999
# Wynblatt, Luise was hired on 30 May 1999
# Kalsbeek, Zvonko was hired on 24 Feb 1999
# Carrera, Akemi was hired on 30 Sep 1999
# Swab, Heekeun was hired on 25 Mar 1999
# Uchoa, Val was hired on 04 Dec 1999
# Gihr, Domenick was hired on 02 Jun 1999
# Krogh, Premal was hired on 09 Jan 1999
# Valtorta, Jacqueline was hired on 27 Apr 1999
# Chleq, Yannis was hired on 16 Jan 1999
# Farris, Mountaz was hired on 28 Apr 1999
# Hegner, Petter was hired on 04 Jul 1999
# Sadowsky, Mariangiola was hired on 01 Feb 1999
# Figueira, Hongzue was hired on 30 Sep 1999
# Ibel, Niclas was hired on 16 Apr 1999
# Schmiedel, Oldrich was hired on 05 Jun 1999
# Camarinopoulos, Kazuhiro was hired on 24 Jan 1999
# Gyimothy, Dayanand was hired on 21 May 1999
# DuCasse, Mahendra was hired on 14 Jan 1999
# Berstel, Berthier was hired on 09 Jun 1999
# Slobodova, Kokou was hired on 05 Apr 1999
# Bage, Garnik was hired on 13 Jan 1999
# Turnbull, Magdalena was hired on 07 Nov 1999
# Veldwijk, Yefim was hired on 02 Apr 1999
# Larfeldt, Gunilla was hired on 14 Mar 1999
# Vuskovic, Hauke was hired on 18 Apr 1999
# Rotem, Turgut was hired on 13 Feb 1999
# Rullman, Qingxiang was hired on 28 Mar 1999
# Lammel, Nectarios was hired on 05 Feb 1999
# Casley, Odysseas was hired on 16 Mar 1999
# Gunderson, Tristan was hired on 26 Apr 1999
# Mawatari, Prasadram was hired on 25 Jul 1999
# Norsworthy, Zeydy was hired on 17 Jun 1999
# Rosis, Halsur was hired on 22 May 1999
# Acton, Shietung was hired on 26 Mar 1999
# Trachtenberg, Abdelaziz was hired on 17 Nov 1999
# Nitsch, Yuping was hired on 13 Apr 1999
# Gien, Gad was hired on 08 Nov 1999
# Rabejac, Menkae was hired on 10 Jan 1999
# Kowalchuk, Boaz was hired on 10 Apr 1999
# Siochi, Yolla was hired on 22 Feb 1999
# Ramaiah, Panayotis was hired on 15 May 1999
# Kropatsch, Matk was hired on 25 Jan 1999
# Nishimukai, Uinam was hired on 14 May 1999
# Majewski, Shigeaki was hired on 26 Jan 1999
# Plesums, Kwangsub was hired on 02 Oct 1999
# Thiran, Uli was hired on 02 Dec 1999
# Ramsey, Petter was hired on 18 Feb 1999
# Wegerle, Yakichi was hired on 06 May 1999
# Riesenhuber, Shan was hired on 17 Jun 1999
# Alencar, Roddy was hired on 22 Mar 1999
# Bahl, Arumugam was hired on 06 Jun 1999
# Michaels, Shih was hired on 05 Jul 1999
# Orlowski, Mohammed was hired on 30 May 1999
# Zastre, Kerhong was hired on 17 Feb 1999
# Tomescu, Atreye was hired on 05 Mar 1999
# Rebaine, Sachem was hired on 21 Apr 1999
# Miyakawa, Takanari was hired on 02 Feb 1999
# Kamble, Yucel was hired on 12 Jan 1999
# Falby, Divine was hired on 05 Mar 1999
# Baak, Xuejun was hired on 09 Apr 1999
# Jansch, Berni was hired on 02 Nov 1999
# Burnard, Rayond was hired on 12 Jan 1999
# Kolvik, Garnik was hired on 30 Dec 1999
# Fioravanti, Denis was hired on 26 Jan 1999
# Zongker, Itzchak was hired on 28 Jan 1999
# Menhoudj, Chaosheng was hired on 04 Mar 1999
# Meszaros, Jahangir was hired on 18 Apr 1999
# Bahl, Elzbieta was hired on 18 Feb 1999
# Luke, Munehiro was hired on 24 Dec 1999
# Szmurlo, Mara was hired on 13 Feb 1999
# Heinisuo, Ingmar was hired on 07 Jun 1999
# Henseler, Kwangjo was hired on 09 Feb 1999
# Monarch, Uwe was hired on 20 Mar 1999
# Lindenbaum, Arve was hired on 20 Aug 1999
# Casley, Qiwen was hired on 30 Aug 1999
# Welham, Khoa was hired on 02 May 1999
# Vural, Subhrajyoti was hired on 17 Oct 1999
# Smeets, Tze was hired on 21 Jun 1999
# Lindqvist, Reuven was hired on 28 Jul 1999
# Duclos, Murthy was hired on 26 Dec 1999
# Mitina, Yuuichi was hired on 11 Mar 1999
# Einsfeld, Kersti was hired on 09 Jan 1999
# Butterworth, Felicidad was hired on 06 May 1999
# Aumann, Xiong was hired on 19 Oct 1999
# Lanzelotte, Bangqing was hired on 30 Jan 1999
# Puoti, Indrajit was hired on 05 Jul 1999
# Lagarias, Frederique was hired on 10 Dec 1999
# Axelband, Suvo was hired on 23 Jan 1999
# Valiente, Tran was hired on 28 Apr 1999
# Pettey, Kwangho was hired on 24 Mar 1999
# Champarnaud, Girolamo was hired on 21 Mar 1999
# Beutelspacher, Ebru was hired on 10 Apr 1999
# Manderick, Teiji was hired on 26 Jul 1999
# Gimarc, Tadahiro was hired on 04 Aug 1999
# Luff, Divier was hired on 28 Mar 1999
# Schlegelmilch, Lansing was hired on 04 May 1999
# Plavsic, Alexius was hired on 21 Nov 1999
# Osgood, Perry was hired on 15 Jul 1999
# Khasidashvili, Marla was hired on 16 Jun 1999
# Yamaashi, Giao was hired on 14 Mar 1999
# Turnbull, Jiong was hired on 17 May 1999
# Cichocki, Torsten was hired on 23 Jul 1999
# Koblick, Kazuhito was hired on 15 Feb 1999
# Nourani, Moti was hired on 28 Oct 1999
# Argence, Nagui was hired on 21 Aug 1999
# Gire, Mohammed was hired on 21 Feb 1999
# Scharstein, Sajjan was hired on 21 Jun 1999
# Andreotta, Rafael was hired on 18 Sep 1999
# Kirkerud, Mona was hired on 26 Jan 1999
# Trogemann, Ebru was hired on 10 Oct 1999
# Gelosh, Paraskevi was hired on 05 Oct 1999
# Busillo, Kellyn was hired on 11 Sep 1999
# Jenevein, Mansur was hired on 12 Jan 1999
# Iisaka, Cullen was hired on 19 Jul 1999
# Valette, Brewster was hired on 12 Feb 1999
# Orlowska, Shalesh was hired on 19 May 1999
# Birke, Xinyu was hired on 10 Aug 1999
# Brendel, Deniz was hired on 19 Jan 1999
# Vandervoorde, Lech was hired on 17 Feb 1999
# Camurati, Halsur was hired on 10 Jul 1999
# Stamatiou, Brewster was hired on 26 Oct 1999
# Rusterholz, Xiaoshan was hired on 08 Mar 1999
# Curless, Hauke was hired on 13 Mar 1999
# Avouris, Szabolcs was hired on 31 Mar 1999
# Bolsens, Abdelghani was hired on 19 Mar 1999
# Meszaros, Shen was hired on 04 Aug 1999
# Itzigehl, Cedric was hired on 23 Aug 1999
# Isard, Mabhin was hired on 28 May 1999
# Peris, Tzu was hired on 17 Feb 1999
# Passino, Mingzeng was hired on 09 Apr 1999
# Plavsic, Berni was hired on 20 Jun 1999
# Beznosov, Mayumi was hired on 13 Mar 1999
# Keohane, Karsten was hired on 18 Mar 1999
# Alblas, Ortrud was hired on 06 Feb 1999
# Stroustrup, Paloma was hired on 31 Jan 1999
# Kieras, Keung was hired on 04 Jun 1999
# Lores, Divine was hired on 22 Jun 1999
# Spinelli, Arif was hired on 17 Apr 1999
# Danner, Flemming was hired on 16 Sep 1999
# Wilharm, Genta was hired on 21 May 1999
# Ariola, Larisa was hired on 27 May 1999
# Ramsey, Duke was hired on 02 Jan 1999
# Meriste, Fay was hired on 18 Feb 1999
# Kropp, Angus was hired on 13 May 1999
# Murrill, Sibyl was hired on 27 Mar 1999
# Oaver, Debaprosad was hired on 16 Jul 1999
# Sherertz, Jiakeng was hired on 23 Feb 1999
# Lorch, Mona was hired on 24 May 1999
# Wroclawski, Magy was hired on 07 Apr 1999
# Hashii, Sugwoo was hired on 26 Jan 1999
# Brodal, Dietrich was hired on 20 Sep 1999
# Schaaf, Chinho was hired on 05 Apr 1999
# Perez, Barna was hired on 02 Apr 1999
# Hooghiemstra, Janche was hired on 12 Apr 1999
# Rodite, Arif was hired on 07 Mar 1999
# Homond, Subhrajyoti was hired on 17 Apr 1999
# Alameldin, Xiaoheng was hired on 19 Jul 1999
# Sooriamurthi, Satyanarayana was hired on 30 Mar 1999
# Takkinen, Karoline was hired on 23 Sep 1999
# Bernardeschi, Zhiguo was hired on 19 Sep 1999
# Szmurlo, Shigeu was hired on 17 Sep 1999
# Terlouw, Xiahua was hired on 01 Jul 1999
# Cyne, Nechama was hired on 16 Jan 1999
# Hoogerwoord, Kazuhiro was hired on 14 Apr 1999
# Puppo, Premsyl was hired on 13 May 1999
# Boissier, Suvo was hired on 18 Jan 1999
# Hanabata, Vitaly was hired on 28 Oct 1999
# Linares, Arvin was hired on 08 Feb 1999
# Marshall, Sergi was hired on 06 Mar 1999
# Gopalakrishnan, Michaela was hired on 13 Apr 1999
# Rassart, Seshu was hired on 04 Apr 1999
# Dalphin, Rosine was hired on 14 Apr 1999
# Adachi, Mingdong was hired on 03 Nov 1999
# Luby, Hidefumi was hired on 29 Jan 1999
# Gniady, Francoise was hired on 13 Mar 1999
# Kornyak, Tsutomu was hired on 20 Apr 1999
# Siprelle, Rafail was hired on 14 Feb 1999
# Bernardeschi, Katsuo was hired on 25 Jan 1999
# Rattan, Aksel was hired on 09 Oct 1999
# Condotta, Filipe was hired on 10 Feb 1999
# Heuser, Hugh was hired on 14 Apr 1999
# Peak, Elvis was hired on 21 Jan 1999
# Baek, Mart was hired on 12 Jun 1999
# Servi, Naraig was hired on 03 May 1999
# Taneja, Heng was hired on 13 Feb 1999
# Clemencon, Peer was hired on 23 Apr 1999
# Ghelli, Remmert was hired on 03 Apr 1999
# Bain, Manton was hired on 20 Jan 1999
# Heiserman, Samphel was hired on 05 May 1999
# Marciano, Rasiah was hired on 25 Nov 1999
# Barriga, Serge was hired on 18 Feb 1999
# Simmen, Baoqiu was hired on 23 Mar 1999
# Rullman, Jianhua was hired on 12 May 1999
# Sury, Stepehn was hired on 14 May 1999
# Baby, Tiina was hired on 29 Aug 1999
# Fandrianto, Shaunak was hired on 16 Apr 1999
# Petersohn, Arra was hired on 09 Jan 1999
# Ellozy, Fumiyo was hired on 18 Jan 1999
# Fujisawa, Rosita was hired on 20 Dec 1999
# Alencar, Kwangsub was hired on 16 Jan 1999
# Rodiger, Duangkaew was hired on 27 Mar 1999
# Marciano, Olivera was hired on 22 Sep 1999
# Smailagic, Lokesh was hired on 08 May 1999
# Karner, Dmitry was hired on 04 Mar 1999
# Chvatal, Randi was hired on 04 Jan 1999
# Setiz, Hercules was hired on 09 Jan 1999
# Dalton, Jacqueline was hired on 16 Apr 1999
# Fontet, Ashish was hired on 19 Nov 1999
# Seghrouchni, Mokhtar was hired on 17 Sep 1999
# Hoppenstand, Fumiya was hired on 31 Mar 1999
# Massonet, Yannis was hired on 26 Mar 1999
# Bahk, Navid was hired on 28 May 1999
# Biran, Shigeaki was hired on 01 Jun 1999
# Heijenga, Alper was hired on 23 Jan 1999
# Biron, Chaoyi was hired on 12 Oct 1999
# Yurov, Chrisa was hired on 12 Jan 1999
# Cochrane, Dharmaraja was hired on 23 Mar 1999
# Ratnaker, Toshimo was hired on 12 May 1999
# Ritcey, Akemi was hired on 05 Jul 1999
# Wixon, Wojceich was hired on 30 Apr 1999
# Bondorf, Yakichi was hired on 01 Jun 1999
# Munawer, Tadanori was hired on 17 Feb 1999
# Strooper, Magdalena was hired on 19 Mar 1999
# Hertweck, Nitsan was hired on 05 Mar 1999
# Pillow, Abdelkader was hired on 21 May 1999
# Bernardeschi, Oldrich was hired on 10 Jun 1999
# Hutton, Susanne was hired on 18 Sep 1999
# DuCasse, Gay was hired on 08 Aug 1999
# Birsak, Rosine was hired on 26 Jan 1999
# Gelosh, Apostol was hired on 31 Mar 1999
# Esteva, Mack was hired on 29 Apr 1999
# Wossner, Samphel was hired on 14 Mar 1999
# Setia, Shushma was hired on 27 Mar 1999
# Stroustrup, Rosli was hired on 11 Jan 1999
# Bottner, Mostafa was hired on 03 Mar 1999
# Farrel, Richard was hired on 29 Jan 1999
# Strandh, Paraskevi was hired on 12 Feb 1999
# Ramsay, Hidefumi was hired on 09 Mar 1999
# Sichman, Insup was hired on 02 Mar 1999
# Sessa, Khatoun was hired on 04 May 1999
# Hettesheimer, Kenroku was hired on 13 Aug 1999
# Eugenio, Zorica was hired on 23 Aug 1999
# Luit, Herbert was hired on 17 Nov 1999
# Kakkar, Beshir was hired on 11 Sep 1999
# Azuma, Val was hired on 22 Jan 1999
# Auria, Ioana was hired on 04 Jul 1999
# Terlouw, Yurii was hired on 25 May 1999
# Simmel, Zine was hired on 09 Jan 1999
# Bashian, Howell was hired on 09 Mar 1999
# Kruskal, Nitsan was hired on 19 Feb 1999
# Heuter, Patricio was hired on 01 Jun 1999
# Matheson, Kazuhira was hired on 15 Feb 1999
# Gimarc, Kotesh was hired on 20 Feb 1999
# Piazza, Renny was hired on 23 Aug 1999
# Marrevee, Tooru was hired on 11 May 1999
# Schauser, Hilari was hired on 22 Nov 1999
# Plessier, Tze was hired on 25 Mar 1999
# Sanella, Gian was hired on 04 Jun 1999
# Pettey, Sahrah was hired on 06 Jul 1999
# Smeets, Abdelwaheb was hired on 07 Jan 1999
# Gerteisen, Patricia was hired on 07 Feb 1999
# Srimani, Karlis was hired on 10 Jul 1999
# Mapelli, JiYoung was hired on 12 Jul 1999
# Karlin, Marit was hired on 23 Jun 1999
# Nourani, Raimond was hired on 25 Feb 1999
# Matzat, Kshitij was hired on 19 Jan 1999
# Stranks, Barna was hired on 04 Feb 1999
# Karcich, Oscal was hired on 18 May 1999
# Rajcani, Gaetan was hired on 21 Mar 1999
# Landherr, Remmert was hired on 15 Oct 1999
# Whitcomb, Kirk was hired on 06 Jan 1999
# Hambrick, Indrajit was hired on 24 Aug 1999
# Ginesta, Gretta was hired on 14 Sep 1999
# Mansanne, Sreenivas was hired on 09 Aug 1999
# Guerreiro, Theirry was hired on 23 Apr 1999
# Merkl, Garnik was hired on 09 Jul 1999
# Garnick, Chaoyi was hired on 12 Jan 1999
# Mandell, Shaz was hired on 14 Feb 1999
# Rikino, Taiji was hired on 29 Jul 1999
# Schauser, Mario was hired on 04 May 1999
# Sidje, Bluma was hired on 19 Mar 1999
# Hiltgen, Kayoko was hired on 07 Sep 1999
# Mandell, Zhenbing was hired on 17 Sep 1999
# Asrin, Hilari was hired on 05 Jan 1999
# Chorvat, Martins was hired on 13 Mar 1999
# Hashii, Chuanyi was hired on 13 Aug 1999
# Karlin, Padma was hired on 28 May 1999
# Michaels, Demos was hired on 05 Jan 1999
# McClure, Giri was hired on 19 Oct 1999
# Karner, Rafail was hired on 06 Feb 1999
# Reeker, Supot was hired on 29 Sep 1999
# Cullers, Utz was hired on 30 Mar 1999
# Angiulli, Giordano was hired on 08 Mar 1999
# Baumann, Karsten was hired on 26 Aug 1999
# Monarch, Hongzhu was hired on 24 Jun 1999
# Riefers, Irene was hired on 04 Apr 1999
# Mellouli, Chirstian was hired on 18 Jun 1999
# Gonthier, Halsur was hired on 02 Feb 1999
# Unno, Fayez was hired on 07 Aug 1999
# Jervis, Maren was hired on 22 Apr 1999
# Danner, Remco was hired on 31 Jan 1999
# Levasseur, Leen was hired on 03 Aug 1999
# Thisen, Hailing was hired on 06 Feb 1999
# Christianini, Manu was hired on 17 May 1999
# Vendrig, Martins was hired on 20 Aug 1999
# Maccarone, Gretta was hired on 31 Mar 1999
# Stifter, Arve was hired on 01 Mar 1999
# Ressouche, Munehiro was hired on 08 Mar 1999
# Blokdijk, Lalit was hired on 01 Feb 1999
# Mayerwieser, Giap was hired on 21 Jan 1999
# Gladwell, Itzchak was hired on 26 Jan 1999
# Ouhyoung, Danny was hired on 26 Oct 1999
# Huxford, Somnath was hired on 17 Apr 1999
# Swist, Xudong was hired on 26 Apr 1999
# Schicker, Youjian was hired on 02 Sep 1999
# Hoogerwoord, Jacqueline was hired on 16 Dec 1999
# Pero, Georgy was hired on 04 Dec 1999
# Kamber, Selwyn was hired on 26 Aug 1999
# Coney, Vesna was hired on 28 Jun 1999
# Flowers, Jinpo was hired on 08 Mar 1999
# Lindenbaum, Lillian was hired on 16 Apr 1999
# DasSarma, Pranav was hired on 20 Mar 1999
# Luca, Mong was hired on 14 Jan 1999
# Orsini, Karlis was hired on 31 Dec 1999
# Stanger, Kokou was hired on 04 May 1999
# Randi, Boutros was hired on 07 May 1999
# Hiroyama, Kyoichi was hired on 02 Mar 1999
# Asrin, Piyush was hired on 12 Feb 1999
# Randt, Masato was hired on 12 Sep 1999
# Khamsi, Etsuo was hired on 25 Jan 1999
# Angot, Theirry was hired on 03 Apr 1999
# Pargaonkar, Younwoo was hired on 20 Jul 1999
# Hammerschmidt, Shigenori was hired on 23 Oct 1999
# Legleitner, Xinglin was hired on 06 Apr 1999
# Erbe, Zdislav was hired on 28 May 1999
# Stanfel, Cristinel was hired on 10 Mar 1999
# Serra, Bedir was hired on 13 Nov 1999
# Raczkowsky, Xiaoqiu was hired on 26 Apr 1999
# McFarlan, Insup was hired on 01 Apr 1999
# Cardazo, Zsolt was hired on 26 Feb 1999
# Gronowski, Bartek was hired on 26 Jul 1999
# Orsini, Jiakeng was hired on 14 Apr 1999
# Luit, Oldrich was hired on 05 Jan 1999
# Simmel, Teruyuki was hired on 16 May 1999
# Passino, Sergi was hired on 20 Jan 1999
# Ravishankar, Ayonca was hired on 07 Apr 1999
# McFarlin, Magy was hired on 23 Oct 1999
# Gaughan, Kristin was hired on 03 Apr 1999
# Peron, Yuichiro was hired on 30 Jan 1999
# Jumpertz, Teruyuki was hired on 28 Feb 1999
# Cochrane, Nechama was hired on 05 Aug 1999
# Mitzlaff, Marco was hired on 13 Feb 1999
# Furudate, Chinya was hired on 25 Mar 1999
# Pena, Uli was hired on 23 Jul 1999
# Journel, Edwin was hired on 02 Jan 1999
# Denos, Behnaam was hired on 27 Jun 1999
# Serot, Gunilla was hired on 09 Jan 1999
# Constantine, Leen was hired on 16 Apr 1999
# Bain, Ymte was hired on 25 Mar 1999
# Famili, Odinaldo was hired on 14 Oct 1999
# Naudin, Yannis was hired on 01 Dec 1999
# Litvinov, Unal was hired on 02 Sep 1999
# Dalton, Gor was hired on 13 Nov 1999
# Carrere, Kyoichi was hired on 29 Jan 1999
# Schmezko, Dinah was hired on 11 Sep 1999
# Seuren, Mizuhito was hired on 25 Aug 1999
# DasSarma, Takahiro was hired on 12 Apr 1999
# Zockler, Bogdan was hired on 04 Jan 1999
# Tagansky, Saeko was hired on 23 Mar 1999
# Azadmanesh, Marlo was hired on 30 Mar 1999
# Linnainmaa, Kasidit was hired on 30 Aug 1999
# Krybus, Pantung was hired on 16 Jan 1999
# Atchley, Pranjal was hired on 12 Mar 1999
# Hopewell, Masako was hired on 29 Aug 1999
# Mungall, Eishiro was hired on 21 May 1999
# Bierman, Yucel was hired on 09 Feb 1999
# Rusmann, Goetz was hired on 26 Jan 1999
# Reutenauer, Elvia was hired on 22 Jan 1999
# Sewelson, Weidon was hired on 28 Feb 1999
# Schueller, Juyoung was hired on 17 Mar 1999
# Perly, Angel was hired on 26 Sep 1999
# Ramalingam, Wonhee was hired on 24 Feb 1999
# Schwabacher, Shahab was hired on 18 Sep 1999
# DeMori, Zhonghui was hired on 12 May 1999
# Kawashimo, Mitchel was hired on 12 Jan 1999
# Imataki, Kitty was hired on 08 Sep 1999
# Preusig, Fumitaka was hired on 29 Jan 1999
# Gyimothy, Tonia was hired on 15 Aug 1999
# Stanger, Shaowei was hired on 24 Apr 1999
# McClure, Val was hired on 30 Aug 1999
# Rosin, Jinya was hired on 21 May 1999
# Staudhammer, Guther was hired on 26 May 1999
# Cannard, Feiyu was hired on 15 Jul 1999
# Siprelle, Chaitali was hired on 27 Jul 1999
# Neiman, Guttorm was hired on 11 Jan 1999
# Clemencon, Yonghong was hired on 19 Feb 1999
# Montresor, Hongzhu was hired on 25 Apr 1999
# Tempesti, Masoud was hired on 05 Jan 1999
# Francisci, Diederik was hired on 18 Jun 1999
# Neiman, Aiman was hired on 18 Apr 1999
# McConalogue, Tonia was hired on 11 Apr 1999
# Thisen, Morrie was hired on 15 Mar 1999
# Kandlur, Kamran was hired on 15 Jul 1999
# Anguita, Tetsushi was hired on 03 Jan 1999
# Pagter, Mana was hired on 05 Feb 1999
# Driscoll, Honesty was hired on 18 Jun 1999
# Sullins, Gal was hired on 02 Jan 1999
# Duclos, Jinxi was hired on 05 Jun 1999
# Peak, Leen was hired on 22 May 1999
# Esposito, Iara was hired on 21 Aug 1999
# Jonsson, Chriss was hired on 20 Mar 1999
# Bahi, Sumali was hired on 14 Jun 1999
# Scharstein, Tadahiro was hired on 03 Oct 1999
# Kusakari, Debaprosad was hired on 21 May 1999
# Garigliano, Emran was hired on 04 Dec 1999
# Merlo, Candido was hired on 28 May 1999
# Piazza, Torsten was hired on 13 Apr 1999
# Asmuth, Jianhao was hired on 13 Mar 1999
# Kirkerud, Patricia was hired on 20 Jul 1999
# Chimia, Divier was hired on 15 Apr 1999
# Bolsens, Sanjoy was hired on 14 May 1999
# Etalle, Junsik was hired on 27 Jul 1999
# Setlzner, Mandell was hired on 07 Sep 1999
# Karner, Seshu was hired on 18 Jan 1999
# Debuse, Uinam was hired on 10 Jun 1999
# Pena, Ranan was hired on 05 Jan 1999
# Swist, Brewster was hired on 26 Mar 1999
# Alameldin, Foong was hired on 06 Jul 1999
# Tokunaga, Maren was hired on 09 Sep 1999
# Kawashima, Marko was hired on 04 Jun 1999
# Champarnaud, Remzi was hired on 12 Oct 1999
# Fargier, Sachar was hired on 27 Jun 1999
# Senzako, Wayne was hired on 26 Jan 1999
# Alvarado, Gritta was hired on 22 Sep 1999
# Gecseg, Shen was hired on 24 Jul 1999
# Garnier, Badri was hired on 22 Aug 1999
# Clouatre, Yucel was hired on 06 Feb 1999
# Speel, Suebskul was hired on 02 Feb 1999
# Litvinov, Tsuneo was hired on 06 Jan 1999
# Haumacher, Ziya was hired on 08 Aug 1999
# Krogh, Tayeb was hired on 05 Jun 1999
# Denti, Xianlong was hired on 12 Apr 1999
# Heydon, Tomoyuki was hired on 27 Feb 1999
# Yeung, Udo was hired on 15 Jan 1999
# Goldhammer, Hironoby was hired on 13 May 1999
# Leslie, Itzchak was hired on 15 Mar 1999
# Erev, Muneo was hired on 29 Nov 1999
# Solares, Haldun was hired on 04 Jul 1999
# Gecsei, Marlo was hired on 05 Jun 1999
# Rajala, Atilio was hired on 07 Sep 1999
# Koshiba, Elvia was hired on 01 Sep 1999
# Godskesen, Roded was hired on 27 Feb 1999
# Zongker, Stevo was hired on 29 Apr 1999
# Budinsky, Aiman was hired on 07 Jun 1999
# Herath, Arch was hired on 29 May 1999
# Bouloucos, Mads was hired on 29 Mar 1999
# Plavsic, Oddvar was hired on 12 Feb 1999
# Hardjono, Taisook was hired on 22 Jul 1999
# Irland, Kannan was hired on 19 Apr 1999
# Quaggetto, Domenico was hired on 24 Oct 1999
# Samarati, Fumitaka was hired on 16 Apr 1999
# Begiun, Chrisa was hired on 16 Aug 1999
# Niizuma, Marke was hired on 10 Jun 1999
# Ghalwash, Urs was hired on 25 Apr 1999
# Rosiles, Roddy was hired on 05 Aug 1999
# Heinisuo, Breannda was hired on 03 Jan 1999
# Wendorf, Douadi was hired on 29 Sep 1999
# Uludag, Zdislav was hired on 09 Apr 1999
# Berendt, Brigham was hired on 03 Jan 1999
# Jervis, Yurii was hired on 16 May 1999
# Beutelspacher, Xinan was hired on 04 May 1999
# Sgarro, Lenore was hired on 10 Jun 1999
# Reinhard, Toshimi was hired on 07 Sep 1999
# Ruther, Eran was hired on 24 Jan 1999
# Ramsey, Achilleas was hired on 03 Feb 1999
# Iisaku, Susanna was hired on 04 Jun 1999
# Shanbhogue, Khalil was hired on 23 Jan 1999
# Eickenmeyer, Remko was hired on 13 Mar 1999
# Baig, Rosalyn was hired on 29 Sep 1999
# Ligten, Sanjay was hired on 09 Jun 1999
# Madeira, Atreye was hired on 31 Mar 1999
# Sommer, Takahira was hired on 30 Mar 1999
# Jahnichen, Leszek was hired on 09 Jul 1999
# Goldhammer, Elvis was hired on 28 Apr 1999
# Poujol, Kellyn was hired on 07 May 1999
# Serra, Remko was hired on 03 Jan 1999
# Ramamoorthy, Mamdouh was hired on 07 Feb 1999
# Pezzoli, Uli was hired on 22 Jan 1999
# Boreale, Richard was hired on 06 Jun 1999
# Hebert, Yuping was hired on 04 Jun 1999
# Gecsei, Jaques was hired on 08 Jun 1999
# Llado, DAIDA was hired on 23 Dec 1999
# Perfilyeva, Nigel was hired on 04 Mar 1999
# Schach, Junsik was hired on 28 Jul 1999
# Staelin, Petter was hired on 18 Mar 1999
# Macedo, Kiyokazu was hired on 31 Jan 1999
# Awdeh, Val was hired on 27 Jan 1999
# Rodham, Xiahua was hired on 04 Mar 1999
# Ramalingam, Heng was hired on 31 Mar 1999
# Fraisse, Jagoda was hired on 15 Jun 1999
# Schneeberger, Jayson was hired on 07 Feb 1999
# Showalter, Lalit was hired on 09 Jan 1999
# Fujisawa, Tadanori was hired on 28 Feb 1999
# Ranta, Utz was hired on 22 Mar 1999
# Kroll, Hein was hired on 19 Mar 1999
# Swick, Becky was hired on 09 Jul 1999
# Heemskerk, Arif was hired on 05 Jan 1999
# Cronan, Owen was hired on 20 Feb 1999
# Akiyama, Shuji was hired on 09 Jun 1999
# Radwan, Weijing was hired on 05 Apr 1999
# Braunschweig, Jaewon was hired on 31 Jan 1999
# Validov, Hein was hired on 13 Feb 1999
# Zuberek, Marsja was hired on 30 Nov 1999
# Prochazka, Yishay was hired on 18 Nov 1999
# Sanella, Sangeeta was hired on 30 Mar 1999
# Socorro, Mario was hired on 08 Feb 1999
# Kornyak, Serenella was hired on 15 Aug 1999
# Murthy, Manton was hired on 06 Apr 1999
# Pluym, Yuping was hired on 26 Oct 1999
# Deverell, Uri was hired on 02 Dec 1999
# Senzako, Xiaoqiang was hired on 24 Mar 1999
# Hertweck, Jeane was hired on 27 Jun 1999
# Srimani, Nahid was hired on 11 Apr 1999
# Fiebach, Arch was hired on 19 Apr 1999
# Krogh, Bikash was hired on 07 Mar 1999
# Waschkowski, Tommaso was hired on 28 Feb 1999
# Taneja, Hisao was hired on 27 Mar 1999
# Kruskal, DeForest was hired on 25 Feb 1999
# Begiun, Reinhard was hired on 27 Jan 1999
# Farrel, Goh was hired on 12 Apr 1999
# Klyachko, Akeel was hired on 01 Sep 1999
# Gilg, Roded was hired on 02 May 1999
# Perry, Vidya was hired on 06 Sep 1999
# Copas, Gladys was hired on 01 Jul 1999
# Mahmud, Manibrata was hired on 31 Mar 1999
# Panangaden, Chiranjit was hired on 19 Aug 1999
# Pollock, Hatsukazu was hired on 10 Oct 1999
# Suermann, Sigeru was hired on 21 Apr 1999
# Jeansoulin, Khosrow was hired on 24 Aug 1999
# Leslie, Emdad was hired on 22 Feb 1999
# Pettit, Shaibal was hired on 30 Mar 1999
# England, Zhongwei was hired on 15 Jan 1999
# Setlzner, Fusako was hired on 16 Feb 1999
# Neiman, Nahid was hired on 09 Jan 1999
# Milicia, Weiye was hired on 28 Apr 1999
# Rettelbach, Guozhong was hired on 18 Jun 1999
# Pettis, Weiru was hired on 23 Feb 1999
# Kroon, Mooi was hired on 22 Feb 1999
# Ratnaker, Younwoo was hired on 22 Apr 1999
# Dusink, DAIDA was hired on 03 Jun 1999
# Sooriamurthi, Gaetan was hired on 12 Nov 1999
# Kusakari, Candida was hired on 14 Aug 1999
# Kavanagh, Luisa was hired on 21 Mar 1999
# Eastman, Yishai was hired on 22 Nov 1999
# Reistad, Constantino was hired on 31 Mar 1999
# Mahnke, Guiseppe was hired on 20 Mar 1999
# Garnick, Idoia was hired on 30 Jun 1999
# Giaccio, Jaideep was hired on 12 May 1999
# Heering, Gunilla was hired on 05 Jul 1999
# Ruther, Chandrasekaran was hired on 10 Mar 1999
# Ozeki, Conrado was hired on 30 May 1999
# McClurg, Jinxi was hired on 28 Mar 1999
# Alencar, Bader was hired on 29 Jan 1999
# Kaiserswerth, Kwangyoen was hired on 05 Jun 1999
# Benner, Sastry was hired on 04 Feb 1999
# Luck, Bader was hired on 18 Mar 1999
# Lamba, Tzvetan was hired on 09 Feb 1999
# Murrill, Cathie was hired on 11 May 1999
# Nanard, Niranjan was hired on 18 May 1999
# Braunschweig, Faiza was hired on 13 Feb 1999
# Siksek, Sanjiv was hired on 29 Mar 1999
# Saoudi, Mostafa was hired on 10 Jun 1999
# Miyakawa, Alexius was hired on 07 Mar 1999
# Hegner, Kwun was hired on 10 Aug 1999
# Aamodt, Gonzalo was hired on 15 Dec 1999
# Zaiane, Zongyan was hired on 13 Sep 1999
# Apsitis, Elvis was hired on 13 Sep 1999
# Hainaut, Alejandra was hired on 15 Aug 1999
# Qiwen, Vishwani was hired on 07 Mar 1999
# Juneja, Lakshmi was hired on 25 Aug 1999
# Hofting, Patricio was hired on 30 Apr 1999
# Birjandi, Domenick was hired on 24 Jan 1999
# Perelgut, Raimond was hired on 03 Mar 1999
# Hellwagner, Martina was hired on 01 Jan 1999
# Comellas, Khaled was hired on 16 Feb 1999
# Birke, Valdiodio was hired on 13 Mar 1999
# Pfau, Dipankar was hired on 26 Jan 1999
# Biran, Gen was hired on 06 Sep 1999
# Cusworth, Fatemeh was hired on 06 Feb 1999
# Zallocco, Yahiko was hired on 26 Jan 1999
# Tsukuda, Chanjung was hired on 25 Jan 1999
# Castellani, Kenton was hired on 20 Apr 1999
# Koshiba, Diederik was hired on 16 Jun 1999
# McAlpine, Gor was hired on 10 Apr 1999
# Furedi, Mari was hired on 28 Feb 1999
# Vecchio, Supot was hired on 18 Apr 1999
# Norsworthy, Elrique was hired on 23 Feb 1999
# Coullard, Yolla was hired on 08 May 1999
# Jeansoulin, Zsolt was hired on 29 Jan 1999
# Trelles, Mansur was hired on 27 Apr 1999
# Kisuki, Radoslaw was hired on 22 Feb 1999
# Unno, Niteen was hired on 22 Jul 1999
# McFarlin, Danco was hired on 16 Mar 1999
# Miyakawa, Marsal was hired on 14 Mar 1999
# Bakhtari, Weiyi was hired on 23 Mar 1999
# Motley, Ute was hired on 13 Jun 1999
# Breugel, Pragnesh was hired on 23 Aug 1999
# Egerstedt, Elvis was hired on 28 Jan 1999
# Dengi, Marla was hired on 11 Apr 1999
# Rissland, Abdelkader was hired on 09 Feb 1999
# Ozery, Venkatesan was hired on 12 Mar 1999
# Langford, Kazuhira was hired on 14 Aug 1999
# Luef, Roddy was hired on 30 Mar 1999
# Mapelli, Munir was hired on 09 Aug 1999
# Lores, Shigenori was hired on 10 Feb 1999
# Hiltgen, Chenxi was hired on 26 Oct 1999
# Ertl, Rosita was hired on 19 Apr 1999
# Ushiama, Morrie was hired on 09 Feb 1999
# Ventosa, Phuoc was hired on 23 May 1999
# Foote, Jeanne was hired on 22 Sep 1999
# Hutter, Wayne was hired on 24 Jan 1999
# Holburn, Abdelkader was hired on 13 Apr 1999
# Wolniewicz, Sivanarayana was hired on 11 Sep 1999
# Kriebel, Theirry was hired on 25 Jul 1999
# Dahlbom, Tze was hired on 28 Aug 1999
# Werthner, Basem was hired on 07 Feb 1999
# Marwedel, Arumugam was hired on 23 Apr 1999
# Morton, Bogdan was hired on 08 Sep 1999
# Peron, Khatoun was hired on 06 Jun 1999
# Henseler, Jiann was hired on 09 Jul 1999
# Langford, Emran was hired on 13 Mar 1999
# Candan, Chenxi was hired on 11 Jun 1999
# Pashtan, Hugh was hired on 30 May 1999
# Willoner, Khosrow was hired on 17 Jun 1999
# Senzako, Zissis was hired on 27 Apr 1999
# Bamford, Lucian was hired on 22 Mar 1999
# Morrow, Mayuko was hired on 04 Jan 1999
# Jansen, Sanjoy was hired on 20 Jul 1999
# Kroon, Val was hired on 01 Apr 1999
# Aloisi, Aria was hired on 17 Apr 1999
# Maksimenko, Supot was hired on 11 Jun 1999
# Wendorf, Xumin was hired on 16 Aug 1999
# Bonifati, Adas was hired on 14 Sep 1999
# Soloway, Danae was hired on 08 Jan 1999
# Portugali, Aram was hired on 01 Feb 1999
# Kakkar, Becky was hired on 19 Apr 1999
# Magliocco, Stein was hired on 11 Sep 1999
# Rothenberg, Manohar was hired on 22 Apr 1999
# Kakkar, Vugranam was hired on 26 Feb 1999
# Larfeldt, Muzhong was hired on 05 Jan 1999
# Lieberherr, Sahrah was hired on 08 Feb 1999
# Schwaller, Pradeep was hired on 05 Feb 1999
# Guting, Menkae was hired on 24 Sep 1999
# Picel, Bartek was hired on 12 Apr 1999
# Erni, Shuky was hired on 12 Apr 1999
# Christianini, Rutger was hired on 14 Apr 1999
# Kemmerer, Moti was hired on 17 Apr 1999
# Brender, Gina was hired on 23 Feb 1999
# Leijenhorst, Maren was hired on 24 May 1999
# Trystram, Fox was hired on 06 May 1999
# Eppinger, Phillip was hired on 04 Dec 1999
# Senzako, Stevo was hired on 23 Feb 1999
# Chachaty, Augustine was hired on 09 Jul 1999
# Stanfel, Makato was hired on 07 Aug 1999
# Halloran, Richard was hired on 31 Jul 1999
# Kleiser, Kolar was hired on 13 Oct 1999
# Hardjono, Takushi was hired on 16 Mar 1999
# Lowrie, Lucian was hired on 12 May 1999
# Babu, Remco was hired on 30 Jan 1999
# Bage, Hatsukazu was hired on 14 May 1999
# Radwan, Denny was hired on 06 Dec 1999
# Ossenbruggen, Subir was hired on 01 Apr 1999
# Zykh, Serif was hired on 14 Apr 1999
# Falck, Munehiro was hired on 15 Jan 1999
# McClurg, Izaskun was hired on 14 Apr 1999
# Henders, Wuxu was hired on 25 May 1999
# Larfeldt, Augustine was hired on 13 Mar 1999
# Wynblatt, Josyula was hired on 05 Aug 1999
# Marchesini, Inderjeet was hired on 11 Jan 1999
# Bondorf, Nishit was hired on 26 Apr 1999
# Schwartzbauer, Udi was hired on 28 Jan 1999
# Gire, Duro was hired on 29 Aug 1999
# Schaap, Chuanti was hired on 22 Jun 1999
# Kabayashi, Syozo was hired on 19 Sep 1999
# Mattern, Jessie was hired on 29 Mar 1999
# Guenter, Badri was hired on 20 Jan 1999
# Ghandeharizadeh, Mohammed was hired on 21 Apr 1999
# Eppinger, Shaowen was hired on 26 Mar 1999
# Spinelli, Tadahiro was hired on 15 Nov 1999
# Fandrianto, Gou was hired on 29 Jan 1999
# Ginneken, Licheng was hired on 14 Oct 1999
# Ouhyoung, Oscar was hired on 26 Jun 1999
# Leuchs, Uma was hired on 27 Aug 1999
# Danlos, Saddek was hired on 17 Jun 1999
# Chvatal, Fay was hired on 21 Jan 1999
# Janetzko, Houman was hired on 19 Feb 1999
# Potthoff, Conrado was hired on 22 Jun 1999
# Walstra, Bader was hired on 24 Jan 1999
# Coorg, Maja was hired on 02 Feb 1999
# Cesareni, Khosrow was hired on 29 Mar 1999
# Holburn, Sanjai was hired on 25 May 1999
# Muhling, JoAnne was hired on 10 Aug 1999
# Christ, Jahangir was hired on 24 Mar 1999
# Panienski, Jamaludin was hired on 20 Feb 1999
# Curless, Soenke was hired on 06 Mar 1999
# Ibel, Vasiliy was hired on 17 Feb 1999
# Murillo, Huai was hired on 20 Aug 1999
# Luck, Masato was hired on 28 Feb 1999
# Jeansoulin, Hilari was hired on 28 Apr 1999
# Ernst, Irena was hired on 28 Sep 1999
# Schwartzbauer, Josyula was hired on 07 Apr 1999
# Rusmann, Licheng was hired on 05 May 1999
# DuBourdieux, Gaurav was hired on 18 Oct 1999
# Fairtlough, Dung was hired on 09 Jul 1999
# Radivojevic, Khatoun was hired on 03 Sep 1999
# Peng, Shigehito was hired on 23 Feb 1999
# Maccarone, Fumiyo was hired on 03 Jun 1999
# Luks, Angel was hired on 06 Jan 1999
# Pocchiola, Tsutomu was hired on 02 Feb 1999
# Kruskal, Alois was hired on 25 Sep 1999
# Moffat, Huiqun was hired on 10 Feb 1999
# Besancenot, Yongmao was hired on 19 Feb 1999
# Capobianchi, Huan was hired on 21 Oct 1999
# Armand, Moheb was hired on 28 Jan 1999
# Thiria, Arunachalam was hired on 16 Sep 1999
# Gilg, Arvind was hired on 07 Jul 1999
# Trumbly, Niclas was hired on 16 Feb 1999
# Raney, Jiafu was hired on 16 Jun 1999
# Luks, Lobel was hired on 28 Feb 1999
# DuCasse, Beshir was hired on 21 Oct 1999
# Bael, Paraskevi was hired on 18 May 1999
# Penn, Joydip was hired on 24 Jun 1999
# Boudaillier, Sudharsan was hired on 23 Feb 1999
# Riexinger, Yagil was hired on 31 Mar 1999
# Petersohn, Marko was hired on 05 Jun 1999
# Kusakabe, Pranay was hired on 13 Feb 1999
# Varman, Denny was hired on 17 Jan 1999
# Kopetz, Mohua was hired on 04 Feb 1999
# Sidje, Mechthild was hired on 08 Mar 1999
# Henseler, Uzi was hired on 10 Jun 1999
# Rosiles, Moss was hired on 26 Oct 1999
# McFarlan, Charmane was hired on 22 Feb 1999
# Heyers, Xumin was hired on 13 Aug 1999
# Fraisse, Baruch was hired on 04 Apr 1999
# Demos, Pantung was hired on 17 Mar 1999
# Heuser, Chriss was hired on 22 Aug 1999
# Rathonyi, Urs was hired on 23 Jan 1999
# Servieres, Shin was hired on 18 Jan 1999
# Chaudhury, Hirochika was hired on 02 Jun 1999
# Marshall, Kazuhiko was hired on 20 Jan 1999
# Wilharm, LiMin was hired on 16 Dec 1999
# Androutsos, Oldrich was hired on 22 Sep 1999
# Theuretzbacher, Willard was hired on 05 Jul 1999
# Nittel, Supot was hired on 02 Jan 1999
# Ballarin, Terresa was hired on 24 Jan 1999
# Papadias, Bokyung was hired on 04 Mar 1999
# Champarnaud, Howell was hired on 08 Apr 1999
# Clemencon, Leah was hired on 03 Sep 1999
# Majewski, Marc was hired on 20 May 1999
# Vesel, Collette was hired on 25 May 1999
# Benaini, Eben was hired on 01 Jan 1999
# Henseler, Constantino was hired on 30 Jun 1999
# Taubenfeld, Ung was hired on 14 Aug 1999
# Ranka, Niteen was hired on 12 Jan 1999
# Puppo, Boriana was hired on 17 Mar 1999
# Waterhouse, Barna was hired on 11 Sep 1999
# Zaumen, Tru was hired on 17 Jun 1999
# Marshall, Martina was hired on 04 Feb 1999
# Thombley, Uri was hired on 12 Oct 1999
# Rajcani, Maris was hired on 26 Mar 1999
# Morrey, Oscar was hired on 23 May 1999
# Sethi, Barry was hired on 13 Jul 1999
# Cmelik, Gino was hired on 28 May 1999
# Rissland, Sukumar was hired on 02 Aug 1999
# Vickson, Franziska was hired on 13 Oct 1999
# Solares, Heekeun was hired on 04 Feb 1999
# Scharstein, Prodip was hired on 14 Oct 1999
# Kawashima, Constantine was hired on 27 Jan 1999
# Rohrbach, Abdelkader was hired on 14 Jun 1999
# Gladwell, Nevio was hired on 11 Mar 1999
# Luck, Piyawadee was hired on 20 Sep 1999
# Cangellaris, Jayesh was hired on 20 Feb 1999
# Homond, Dmitri was hired on 27 Jan 1999
# Yurek, Lalit was hired on 16 Mar 1999
# Chenoweth, Izaskun was hired on 31 Jul 1999
# Wielonsky, Lalit was hired on 16 Dec 1999
# Zobel, Fai was hired on 17 Apr 1999
# Taubenfeld, Gita was hired on 15 May 1999
# Liedekerke, Mooi was hired on 30 Jan 1999
# Kalorkoti, Tomofumi was hired on 25 Jan 1999
# Servi, Christ was hired on 15 Jan 1999
# Morrey, Guiseppe was hired on 24 Apr 1999
# Birta, Adel was hired on 27 May 1999
# Huhdanpaa, Aleksander was hired on 28 Jan 1999
# Potthoff, Atreye was hired on 05 Jan 1999
# Merkl, Muzhong was hired on 09 Feb 1999
# Munke, Fai was hired on 05 Sep 1999
# Wroclawski, Aamod was hired on 22 Aug 1999
# Kabayashi, Patricia was hired on 12 Nov 1999
# Heping, Piyush was hired on 14 Sep 1999
# Basawa, Trygve was hired on 16 Sep 1999
# Renear, Guozhong was hired on 12 Dec 1999
# Ranai, Berthier was hired on 12 Aug 1999
# Socorro, Kiyomitsu was hired on 30 Apr 1999
# Iwayama, Tzvetan was hired on 01 Apr 1999
# Bressoud, Uzi was hired on 10 Jan 1999
# Knightly, Tua was hired on 15 Apr 1999
# Lienhardt, Stabislas was hired on 28 Feb 1999
# Sgarro, Willard was hired on 15 Apr 1999
# Katiyar, Marit was hired on 08 Jul 1999
# Perez, Poornachandra was hired on 26 Aug 1999
# Noriega, Willard was hired on 15 Sep 1999
# Ponthieu, Rafael was hired on 13 May 1999
# Esteva, Horward was hired on 22 Aug 1999
# Pagter, Xiaoqiu was hired on 21 Apr 1999
# Pell, Zejun was hired on 24 Apr 1999
# Broomell, Khun was hired on 01 Oct 1999
# Rabehasaina, Tomokazu was hired on 24 Jun 1999
# Kisuki, Tze was hired on 27 Jun 1999
# Linnainmaa, Kitty was hired on 09 Jun 1999
# Vesel, Goetz was hired on 24 Jan 1999
# Kaltofen, Bedrich was hired on 26 Apr 1999
# Cunliffe, Fei was hired on 05 Jan 1999
# Baezner, Zhiguo was hired on 26 Nov 1999
# Penttonen, Khaled was hired on 27 Jun 1999
# Bouloucos, Arvind was hired on 27 Jul 1999
# Hegner, Fabrizio was hired on 21 Feb 1999
# Gien, Angel was hired on 12 Jun 1999
# Giaccio, Ute was hired on 15 Apr 1999
# Edelhoff, Filipp was hired on 13 Jan 1999
# Gulla, Slavian was hired on 16 Jan 1999
# Gaughan, Radhia was hired on 18 Oct 1999
# Hitomi, Giordano was hired on 07 Aug 1999
# Goodrum, Elvis was hired on 14 Apr 1999
# Krzyzanowski, Beshir was hired on 21 Jun 1999
# Ambroszkiewicz, Gal was hired on 29 Sep 1999
# Sichman, Jeanne was hired on 27 Sep 1999
# Jahnichen, Abdelaziz was hired on 02 Jan 1999
# Herath, Shichao was hired on 11 Feb 1999
# Cronin, Branimir was hired on 14 Feb 1999
# Wiegley, Xiaocheng was hired on 10 May 1999
# Itschner, Leaf was hired on 07 Feb 1999
# Kaelbling, Naftaly was hired on 19 Jul 1999
# Ghemri, Olivera was hired on 19 Jan 1999
# Ohori, Mong was hired on 26 Jun 1999
# Honiden, Ranga was hired on 26 Feb 1999
# Montresor, Olivera was hired on 18 Feb 1999
# Kilgore, Uta was hired on 22 Apr 1999
# Ladret, Tayeb was hired on 13 Jan 1999
# Melter, Arlette was hired on 09 Mar 1999
# Stavenow, Kwee was hired on 24 Oct 1999
# Denis, Martien was hired on 21 Mar 1999
# Denti, Xuejun was hired on 20 Jan 1999
# Nanard, Mariusz was hired on 25 Jan 1999
# Landherr, Adly was hired on 13 Jan 1999
# Muhling, Jaber was hired on 05 Sep 1999
# Laurillard, Nathalie was hired on 27 Mar 1999
# Nations, Shaibal was hired on 17 May 1999
# Georgakopoulos, Isamu was hired on 22 Feb 1999
# Zielinski, Miyeon was hired on 07 Feb 1999
# Salinas, Alois was hired on 15 Feb 1999
# Dehkordi, Nathan was hired on 10 Jan 1999
# Quaggetto, Licheng was hired on 14 Aug 1999
# Kaiserswerth, Saeed was hired on 26 Jun 1999
# Antonakopoulos, Morrie was hired on 27 Apr 1999
# Comyn, Kankanahalli was hired on 06 Feb 1999
# Schlegelmilch, Danae was hired on 02 Apr 1999
# Syrzycki, Valeska was hired on 20 Jul 1999
# Picco, Younwoo was hired on 01 Jan 1999
# Perfilyeva, Ranan was hired on 27 Apr 1999
# Jiang, Hyuckchul was hired on 10 Aug 1999
# Matzat, Gully was hired on 16 Feb 1999
# Pelc, Arumugam was hired on 17 Aug 1999
# Wiegley, Cathie was hired on 09 Mar 1999
# McClurg, Mats was hired on 24 Aug 1999
# Bellmore, Arnd was hired on 28 Apr 1999
# Litecky, Adil was hired on 12 Oct 1999
# Solares, Sandeepan was hired on 30 Nov 1999
# Vernadat, Kiyokazu was hired on 29 Aug 1999
# Smeets, Hilari was hired on 27 Jun 1999

# %%
print(cnx.is_connected())
if cnx.is_connected():
    cnx.ping()
# Out:
# False

# %%
from __future__ import print_function

from decimal import Decimal
from datetime import datetime, date, timedelta

import mysql.connector

# Connect with the MySQL Server
# cnx = mysql.connector.connect(user='scott', database='employees')
cnx = mysql.connector.connect(user='root', password='root', database='employees')

# Get two buffered cursors
curA = cnx.cursor(buffered=True)
curB = cnx.cursor(buffered=True)

# Query to get employees who joined in a period defined by two dates
query = (
  "SELECT s.emp_no, salary, from_date, to_date FROM employees AS e "
  "LEFT JOIN salaries AS s USING (emp_no) "
  "WHERE to_date = DATE('9999-01-01')"
  "AND e.hire_date BETWEEN DATE(%s) AND DATE(%s)")

# UPDATE and INSERT statements for the old and new salary
update_old_salary = (
  "UPDATE salaries SET to_date = %s "
  "WHERE emp_no = %s AND from_date = %s")
insert_new_salary = (
  "INSERT INTO salaries (emp_no, from_date, to_date, salary) "
  "VALUES (%s, %s, %s, %s)")

# Select the employees getting a raise
curA.execute(query, (date(2000, 1, 1), date(2000, 12, 31)))

# Iterate through the result of curA
for (emp_no, salary, from_date, to_date) in curA:

  # Update the old and insert the new salary
  new_salary = int(round(salary * Decimal('1.15')))
  curB.execute(update_old_salary, (tomorrow, emp_no, from_date))
  curB.execute(insert_new_salary,
               (emp_no, tomorrow, date(9999, 1, 1,), new_salary))

  # Commit the changes
  cnx.commit()

cnx.close()

# %% [markdown]
# ⊕ [Python Database Connection Pooling with MySQL [Complete Guide]](https://pynative.com/python-database-connection-pooling-with-mysql/)
#
# * use MySQLConnectionPool.get_connection() method. Using this method application can get the connection object from a connection pool. This method returns a connection from the pool. If all connections are in use or pool is empty it raises a `PoolError`.
#
# * we can use a PooledMySQLConnection.close() method to close the pooled connection instance.
# This method doesn’t close the connection but returns the connection to the connection pool to serve the next request. i.e., it returns a pooled connection to its connection pool.
# * Using pooling.PooledMySQLConnection class constructor, we can get a pooled connection. This constructor takes connection pool and connection arguments and returns a pooled connection instance.
# * Using a MySQLConnectionPool.add_connection() method we can add a new or existing MySQL Connection to the pool. If the pool is full or exceeding its limit, it raises a PoolError.

# %%
import mysql.connector
from mysql.connector import Error
from mysql.connector import pooling
try:
    connection_pool = pooling.MySQLConnectionPool(pool_name="native_pool",                                                  
                                                  pool_size=1,
                                                  pool_reset_session=True,
                                                  host='localhost',
                                                  database='test',
                                                  user='root',
                                                  password='root')
    print ("Printing connection pool properties ")
    print("Connection Pool Name - ", connection_pool.pool_name)
    print("Connection Pool Size - ", connection_pool.pool_size)

    # Get connection object from a pool
    connection_object = connection_pool.get_connection()


    if connection_object.is_connected():
       db_Info = connection_object.get_server_info()
       print("Connected to MySQL database using connection pool ... MySQL Server version on ",db_Info)

       cursor = connection_object.cursor()
       cursor.execute("select database();")
       record = cursor.fetchone()
       print ("Your connected to - ", record)

except Error as e :
    print ("Error while connecting to MySQL using Connection pool ", e)
finally:
    #closing database connection.
    if(connection_object.is_connected()):
        cursor.close()
        connection_object.close()
        print("MySQL connection is closed")
# Out:
# Printing connection pool properties
# Connection Pool Name -  native_pool
# Connection Pool Size -  1
# Connected to MySQL database using connection pool ... MySQL Server version on  8.0.19
# Your connected to -  ('test',)
# MySQL connection is closed
