# %% [markdown]
# * preqs: sagas/0.2.0, saai/0.2.4

# %%
from sagas.nlu.ruleset_procs import list_words, cached_chunks, get_main_domains
from sagas.conf.conf import cf
from sagas.tracker_jupyter import enable_jupyter_tracker
enable_jupyter_tracker()

# There are not many trees in the desert.
sents='Tidak banyak pohon di gurun.'
lang='id'
domain='root_domains'
chunks = cached_chunks(sents, lang, cf.engine(lang))
domains = chunks[domain]
domains
# Out:
# [{'index': '3',
#   'text': 'pohon',
#   'lemma': 'pohon',
#   'upos': 'NOUN',
#   'xpos': 'NSD',
#   'feats': 'Number=Sing',
#   'governor': 0,
#   'dependency_relation': 'root',
#   'punct': [{'index': '6',
#     'text': '.',
#     'lemma': '.',
#     'upos': 'PUNCT',
#     'xpos': 'Z--',
#     'feats': '_',
#     'governor': 3,
#     'dependency_relation': 'punct'}],
#   'nmod': [{'index': '5',
#     'text': 'gurun',
#     'lemma': 'gurun',
#     'upos': 'NOUN',
#     'xpos': 'NSD',
#     'feats': 'Number=Sing',
#     'governor': 3,
#     'dependency_relation': 'nmod',
#     'case': [{'index': '4',
#       'text': 'di',
#       'lemma': 'di',
#       'upos': 'ADP',
#       'xpos': 'R--',
#       'feats': '_',
#       'governor': 5,
#       'dependency_relation': 'case'}]}],
#   'advmod': [{'index': '1',
#     'text': 'Tidak',
#     'lemma': 'tidak',
#     'upos': 'PART',
#     'xpos': 'G--',
#     'feats': 'Polarity=Neg',
#     'governor': 3,
#     'dependency_relation': 'advmod'},
#    {'index': '2',
#     'text': 'banyak',
#     'lemma': 'banyak',
#     'upos': 'ADV',
#     'xpos': 'B--',
#     'feats': 'NumType=Card|PronType=Ind',
#     'governor': 3,
#     'dependency_relation': 'advmod'}]}]

# %%
from sagas.nlu.uni_remote_viz import list_contrast, display_doc_deps
display_doc_deps(chunks['doc'], None)
# Out:
# ✁ dependency-graph. -------------------------
#   index    text   lemma   upos xpos
# 0     1   Tidak   tidak   PART  G--
# 1     2  banyak  banyak    ADV  B--
# 2     3   pohon   pohon   NOUN  NSD
# 3     4      di      di    ADP  R--
# 4     5   gurun   gurun   NOUN  NSD
# 5     6       .       .  PUNCT  Z--

# %%
[w.text for w in chunks['doc'].words]
# Out:
# ['Tidak', 'banyak', 'pohon', 'di', 'gurun', '.']

# %%
name, domains=get_main_domains(sents, lang, cf.engine(lang))
domains
# Out:
# [{'index': '3',
#   'text': 'pohon',
#   'lemma': 'pohon',
#   'upos': 'NOUN',
#   'xpos': 'NSD',
#   'feats': 'Number=Sing',
#   'governor': 0,
#   'dependency_relation': 'root',
#   'punct': [{'index': '6',
#     'text': '.',
#     'lemma': '.',
#     'upos': 'PUNCT',
#     'xpos': 'Z--',
#     'feats': '_',
#     'governor': 3,
#     'dependency_relation': 'punct'}],
#   'advmod': [{'index': '1',
#     'text': 'Tidak',
#     'lemma': 'tidak',
#     'upos': 'PART',
#     'xpos': 'G--',
#     'feats': 'Polarity=Neg',
#     'governor': 3,
#     'dependency_relation': 'advmod'},
#    {'index': '2',
#     'text': 'banyak',
#     'lemma': 'banyak',
#     'upos': 'ADV',
#     'xpos': 'B--',
#     'feats': 'NumType=Card|PronType=Ind',
#     'governor': 3,
#     'dependency_relation': 'advmod'}],
#   'nmod': [{'index': '5',
#     'text': 'gurun',
#     'lemma': 'gurun',
#     'upos': 'NOUN',
#     'xpos': 'NSD',
#     'feats': 'Number=Sing',
#     'governor': 3,
#     'dependency_relation': 'nmod',
#     'case': [{'index': '4',
#       'text': 'di',
#       'lemma': 'di',
#       'upos': 'ADP',
#       'xpos': 'R--',
#       'feats': '_',
#       'governor': 5,
#       'dependency_relation': 'case'}]}]}]

# %%
from sagas.kit.analysis_kit import vis_domains
sents='What do you think about the war?'
lang='en'
domain='subj_domains' # 'verb_domains', 'aux_domains'
vis_domains(sents, lang, domain)

# %%
from sagas.kit.analysis_kit import vis_domains
for v in vis_domains('What do you think about the war?', 'en', all_subsents=True): display(v)

# %%
from sagas.kit.analysis_kit import vis_domains
for v in vis_domains('Dia mendapat peran utama di film ini.', 'id', all_subsents=True): display(v)

# %%
from sagas.kit.analysis_kit import vis_domains
for v in vis_domains('あなたにとってお金は大切ですか？', 'ja', engine='corenlp', all_subsents=True): display(v)

# %%
from sagas.kit.analysis_kit import vis_domains
sents='Monique raccroche le téléphone pendant que Michel arrive.'
for v in vis_domains(sents, 'fr', engine='corenlp', all_subsents=True): display(v)
